# %%
np.arange(1, 101 + 1, 5)
# Out:
# array([  1,   6,  11,  16,  21,  26,  31,  36,  41,  46,  51,  56,  61,
#         66,  71,  76,  81,  86,  91,  96, 101])

# %%
import os
import numpy as np
from tqdm import tqdm
from multiprocessing import Pool, cpu_count

import torch

import neurox.interpretation.utils as utils
import neurox.interpretation.ablation as ablation
import neurox.interpretation.linear_probe as linear_probe

from ttsxai.utils.utils import read_ljs_metadata


log_dir = '/nas/users/dahye/kw/tts/ttsxai/logs/probe_tacotron2_duration'
data_activation_dir = "/nas/users/dahye/kw/tts/ttsxai/data_activation/LJSpeech/tacotron2_waveglow"

# %%
a = get_neuron_ordering_for_linear_regression(probe)

# %%
def get_random_neurons(probe, probability):
    """
    Get random neurons from a trained probe.

    This method returns a random set of neurons based on the probability. Each
    neuron is either discarded or included based on a uniform random variable's
    value (included if its less than probability, discarded otherwise)

    Parameters
    ----------
    probe : interpretation.linear_probe.LinearProbe
        Trained probe model
    probability : float
        Real number between 0 and 1, with 0 representing no selection and 1
        representing selection of all neurons.

    Returns
    -------
    random_neurons : numpy.ndarray
        Numpy array with random neurons

    """
    weights = list(probe.parameters())[0].data.cpu()
    weights = np.abs(weights.numpy())

    mask = np.random.random((weights.shape[1],))
    idx = np.where(mask <= probability)[0]

    return idx

get_random_neurons(probe, 0.1).shape
# Out:
# (212,)

# %%
data_dict_train = np.load(os.path.join(log_dir, 'data', 'train_data.npz'), allow_pickle=True)
X_train = data_dict_train['X']
y_train = data_dict_train['y']

data_dict_test = np.load(os.path.join(log_dir, 'data', 'test_data.npz'), allow_pickle=True)
X_test = data_dict_test['X']
y_test = data_dict_test['y']

# ignore zero duration
X_train = X_train[y_train > 0]
y_train = y_train[y_train > 0]
X_test = X_test[y_test > 0]
y_test = y_test[y_test > 0]

# we predict log duration
y_train = np.log(y_train)
y_test = np.log(y_test)

probe = linear_probe.LinearProbe(X_train.shape[1], 1)

# %%
def get_neuron_ordering_for_linear_regression(probe, search_stride=100):
    """
    Get neuron ordering for a specific class from a trained probe.

    Parameters
    ----------
    probe : interpretation.linear_probe.LinearProbe
        Trained probe model
    search_stride : int, optional
        Number of steps to divide the weight mass percentage

    Returns
    -------
    neuron_ordering : numpy.ndarray
        Array of neurons ordered by their importance for the specified class
    """
    # class_idx = class_to_idx[class_name]
    weights = list(probe.parameters())[0].data.cpu().numpy()
    abs_weights = np.abs(weights[0])
    si = np.argsort(abs_weights)[::-1]
    print(si[:5])
    print(si[-5:])
    print(abs_weights[si])

    neuron_orderings = []
    for p in range(1, search_stride + 1):
        percentage = p / search_stride
        total_mass = np.sum(abs_weights)
        sorted_idx = np.argsort(abs_weights)[::-1]  # Sort in descending order
        cum_sums = np.cumsum(abs_weights[sorted_idx])
        selected_neurons = sorted_idx[cum_sums <= total_mass * percentage]
        neuron_orderings.extend(selected_neurons)

    # Remove duplicates while preserving order
    neuron_ordering = list(dict.fromkeys(neuron_orderings))

    return np.array(neuron_ordering)

# %%
get_neuron_ordering_for_linear_regression(probe)
# Out:
# [1851  911  923  778 1865]
# [1456   99   59  590  707]
# [2.2092573e-02 2.2089176e-02 2.2084175e-02 ... 1.8686858e-05 1.7975630e-05
#  1.0325978e-05]
# array([1851,  911,  923, ...,   59,  590,  707])

# %%
data_dict = dict(np.load(os.path.join(log_dir, 'scores', 'mlpprobe.npz')))
data_dict['test']
# Out:
# array([0.07462117, 0.07352313, 0.07349195], dtype=float32)

# %%
data_dict = dict(np.load(os.path.join(log_dir, 'scores', 'probe_noreg.npz')))
data_dict['test']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_483738/1627422112.py in <module>
# ----> 1 data_dict = dict(np.load(os.path.join(log_dir, 'scores', 'probe_noreg.npz')))
#       2 data_dict['test']
#
# ~/anaconda3/envs/ttsxai/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nas/users/dahye/kw/tts/ttsxai/logs/probe_tacotron2_duration/scores/probe_noreg.npz'

# %%
for k in range(4):
    data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_layer_{k}_noreg.npz')))
    print(data_dict['test'][-1])
# Out:
# 0.121908344
# 0.09826692
# 0.0920727
# 0.084278084

# %%
for k in range(4):
    data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_layer_{k}.npz')))
    print(data_dict['test'][-1])
# Out:
# 0.1406279
# 0.11491856
# 0.0981596
# 0.08764746

# %%
1	0.31382546
6	0.28406215
11	0.18350205
16	0.18289219
21	0.17996849
26	0.16872445
31	0.1597819
36	0.15191793
41	0.13707356
46	0.13129628
51	0.12141481
56	0.1132296
61	0.10900084
66	0.10591225
71	0.10438707
76	0.101809256
81	0.099342935

# %%
1
6
11
16
21
26
31
36
41
46
51
56
61
66
71
76
81

# %%
0.3218547
0.3184304
0.27302012
0.2604244
0.25735116
0.24943794
0.24705687
0.24389279
0.243521
0.24152999
0.23963873
0.23363096
0.22532807
0.21038997
0.20773752
0.20760679
0.19826505
0.19652925
0.18913865
0.1773968
0.1771514

# %%
ordering = get_neuron_ordering_for_linear_regression(probe)

# %%
ordering
# Out:
# array([1851,  911,  923, ...,   59,  590,  707])

# %%
orderling = ordering[::-1]

# %%
orderling
# Out:
# array([ 707,  590,   59, ...,  923,  911, 1851])

# %%
for k in range(1, 101+1, 5):
    data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_selected_bottom_{k}_noreg.npz')))
    # print(k)#, data_dict['test'][-1], sep='\t')
    print(data_dict['test'][-1])
    # print('\n')
# Out:
# 0.3218547
# 0.3184304
# 0.27302012
# 0.2604244
# 0.25735116
# 0.24943794
# 0.24705687
# 0.24389279
# 0.243521
# 0.24152999
# 0.23963873
# 0.23363096
# 0.22532807
# 0.21038997
# 0.20773752
# 0.20760679
# 0.19826505
# 0.19652925
# 0.18913865
# 0.1773968
# 0.1771514

# %%
for k in range(1, 101+1, 5):
    data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_selected_{k}.npz')))
    # print(k)#, data_dict['test'][-1], sep='\t')
    print(data_dict['test'][-1])
    # print('\n')
# Out:
# 0.31382546
# 0.28406215
# 0.18350205
# 0.18289219
# 0.17996849
# 0.16872445
# 0.1597819
# 0.15191793
# 0.13707356
# 0.13129628
# 0.12141481
# 0.1132296
# 0.10900084
# 0.10591225
# 0.10438707
# 0.101809256
# 0.099342935
# 0.09711998
# 0.09277097
# 0.090178065
# 0.08916971

# %%
for k in range(1, 101+1, 5):
    data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_selected_{k}_noreg.npz')))
    # print(k)#, data_dict['test'][-1], sep='\t')
    print(data_dict['test'][-1])
    # print('\n')
# Out:
# 0.32171428
# 0.31003788
# 0.28170297
# 0.27537477
# 0.27299696
# 0.24196056
# 0.23885222
# 0.22891366
# 0.21511868
# 0.21135941
# 0.20518248
# 0.1943123
# 0.18957333
# 0.18737522
# 0.18533146
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_483738/508025580.py in <module>
#       1 for k in range(1, 101+1, 5):
# ----> 2     data_dict = dict(np.load(os.path.join(log_dir, 'scores', f'probe_selected_{k}_noreg.npz')))
#       3     # print(k)#, data_dict['test'][-1], sep='\t')
#       4     print(data_dict['test'][-1])
#       5     # print('\n')
#
# ~/anaconda3/envs/ttsxai/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nas/users/dahye/kw/tts/ttsxai/logs/probe_tacotron2_duration/scores/probe_selected_76_noreg.npz'

# %%
    # load pre-trained probe
    probe = linear_probe.train_logistic_regression_probe(
        X, y, lambda_l1=0.001, lambda_l2=0.001,
        num_epochs=0)
    probe.load_state_dict(
        torch.load(os.path.join(log_dir, 'models', 'probe.pth')))

# %%
# data_dict_train = np.load(os.path.join(log_dir, 'data', 'train_data.npz'), allow_pickle=True)
# X_train = data_dict_train['X']
# y_train = data_dict_train['y']

data_dict_test = np.load(os.path.join(log_dir, 'data', 'test_data.npz'), allow_pickle=True)
X_test = data_dict_test['X']
y_test = data_dict_test['y']

# ignore zero duration
# X_train = X_train[y_train > 0]
# y_train = y_train[y_train > 0]
X_test = X_test[y_test > 0]
y_test = y_test[y_test > 0]

# we predict log duration
# y_train = np.log(y_train)
y_test = np.log(y_test)

# probe = linear_probe.LinearProbe(X_train.shape[1], 1)

# %%
probe = linear_probe.LinearProbe(X_test.shape[1], 1)

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable

from neurox.interpretation.linear_probe import l1_penalty, l2_penalty, LinearProbe

# %%
X_train=X_test
y_train=y_test
task_type="regression"
lambda_l1=0
lambda_l2=0
num_epochs=1
batch_size=64
learning_rate=0.001
# probe=None

progressbar = utils.get_progress_bar()
print("Training %s probe" % (task_type))
# Check if we can use GPU's for training
use_gpu = torch.cuda.is_available()

if lambda_l1 is None or lambda_l2 is None:
    raise ValueError("Regularization weights cannot be None")

print("Creating model...")
if task_type == "classification":
    num_classes = len(set(y_train))
    if num_classes <= 1:
        raise ValueError(
            "Classification problem must have more than one target class"
        )
else:
    num_classes = 1
print("Number of training instances:", X_train.shape[0])
if task_type == "classification":
    print("Number of classes:", num_classes)

if probe is None:
    probe = LinearProbe(X_train.shape[1], num_classes)
if use_gpu:
    probe = probe.cuda()

if task_type == "classification":
    criterion = nn.CrossEntropyLoss()
elif task_type == "regression":
    criterion = nn.MSELoss()
else:
    raise ValueError("Invalid `task_type`")

optimizer = torch.optim.Adam(probe.parameters(), lr=learning_rate)

X_tensor = torch.from_numpy(X_train)
y_tensor = torch.from_numpy(y_train)

for epoch in range(num_epochs):
    num_tokens = 0
    avg_loss = 0
    for inputs, labels in progressbar(
        utils.batch_generator(X_tensor, y_tensor, batch_size=batch_size),
        desc="epoch [%d/%d]" % (epoch + 1, num_epochs),
    ):
        num_tokens += inputs.shape[0]
        if use_gpu:
            inputs = inputs.cuda()
            labels = labels.cuda()
        inputs = inputs.float()
        inputs = Variable(inputs)
        labels = Variable(labels)

        # Forward + Backward + Optimize
        # optimizer.zero_grad()

        outputs = probe(inputs)
        if task_type == "regression":
            outputs = outputs.squeeze()
        weights = list(probe.parameters())[0]
        loss = (
            criterion(outputs, labels)
            + lambda_l1 * l1_penalty(weights)
            + lambda_l2 * l2_penalty(weights)
        )
        # loss.backward()
        # optimizer.step()

        avg_loss += loss.item()
        print(loss.item(), num_tokens)
        # break

    print(
        "Epoch: [%d/%d], Loss: %.4f"
        % (epoch + 1, num_epochs, avg_loss / num_tokens)
    )
# Out:
# Training regression probe
# Creating model...
# Number of training instances: 33942
# /home/dahye/anaconda3/envs/ttsxai/lib/python3.7/site-packages/ipykernel_launcher.py:54: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# epoch [1/1]: 0it [00:00, ?it/s]
# 3.4089431762695312 64
# 3.653441905975342 128
# 3.6800765991210938 192
# 3.7993295192718506 256
# 3.760315418243408 320
# 3.669862985610962 384
# 3.481282949447632 448
# 4.594367027282715 512
# 3.500903606414795 576
# 3.8371059894561768 640
# 3.9819250106811523 704
# 3.6700704097747803 768
# 4.37565279006958 832
# 4.1844801902771 896
# 4.0132293701171875 960
# 3.435898542404175 1024
# 3.790529251098633 1088
# 3.8998231887817383 1152
# 3.6397061347961426 1216
# 3.6958298683166504 1280
# 4.028511047363281 1344
# 4.026883125305176 1408
# 4.601248741149902 1472
# 4.196177959442139 1536
# 3.6182403564453125 1600
# 4.037708282470703 1664
# 4.045098304748535 1728
# 4.20054292678833 1792
# 3.93361496925354 1856
# 3.776142120361328 1920
# 4.2568769454956055 1984
# 3.8073465824127197 2048
# 3.6250782012939453 2112
# 4.056900978088379 2176
# 4.106441497802734 2240
# 3.3177528381347656 2304
# 4.61070442199707 2368
# 3.7675700187683105 2432
# 4.101977348327637 2496
# 3.6550137996673584 2560
# 3.709392547607422 2624
# 3.440361976623535 2688
# 3.899653911590576 2752
# 3.8779208660125732 2816
# 3.629152774810791 2880
# 3.791842222213745 2944
# 4.180411338806152 3008
# 3.6022884845733643 3072
# 3.384639263153076 3136
# 3.6160695552825928 3200
# 4.041895866394043 3264
# 4.273064613342285 3328
# 3.693594455718994 3392
# 3.923825740814209 3456
# 3.832907199859619 3520
# 3.695465087890625 3584
# 3.6492974758148193 3648
# 3.732255697250366 3712
# 3.913865089416504 3776
# 4.134868621826172 3840
# 3.9366073608398438 3904
# 3.3597970008850098 3968
# 4.061733722686768 4032
# 3.9029533863067627 4096
# 3.848228931427002 4160
# 4.2902703285217285 4224
# 3.7369964122772217 4288
# 4.062356948852539 4352
# 3.5242466926574707 4416
# 3.9957568645477295 4480
# 3.922572135925293 4544
# 3.81795597076416 4608
# 3.7108654975891113 4672
# 4.1267924308776855 4736
# 4.134594917297363 4800
# 4.003452301025391 4864
# 3.524970054626465 4928
# 3.583836555480957 4992
# 4.015827178955078 5056
# 3.8231496810913086 5120
# 3.637610912322998 5184
# 4.262320518493652 5248
# 3.7617299556732178 5312
# 3.4911530017852783 5376
# 3.5656509399414062 5440
# 4.317543983459473 5504
# 4.535810947418213 5568
# 3.373701572418213 5632
# 3.972377300262451 5696
# 3.5481228828430176 5760
# 3.640817165374756 5824
# 3.580644130706787 5888
# 3.9692866802215576 5952
# 3.815711259841919 6016
# 3.9768667221069336 6080
# 3.963675022125244 6144
# 3.984144687652588 6208
# 3.7966442108154297 6272
# 3.674048900604248 6336
# 3.721407413482666 6400
# 4.131433486938477 6464
# 4.4824066162109375 6528
# 3.6985397338867188 6592
# 3.2636029720306396 6656
# 4.044061660766602 6720
# 3.433900833129883 6784
# 3.527346611022949 6848
# 3.779613733291626 6912
# 3.557758331298828 6976
# 4.121771812438965 7040
# 3.8125038146972656 7104
# 3.854140281677246 7168
# 3.8551883697509766 7232
# 3.673625946044922 7296
# 3.6283257007598877 7360
# 4.100780487060547 7424
# 3.768716335296631 7488
# 4.053115367889404 7552
# 4.062349796295166 7616
# 3.809101104736328 7680
# 3.2810769081115723 7744
# 3.5943479537963867 7808
# 3.5889625549316406 7872
# 3.8144478797912598 7936
# 4.135614395141602 8000
# 3.875997304916382 8064
# 3.8637685775756836 8128
# 3.8321073055267334 8192
# 3.696991443634033 8256
# 3.653388023376465 8320
# 4.400903701782227 8384
# 4.085477828979492 8448
# 3.685253620147705 8512
# 3.5934362411499023 8576
# 3.887965679168701 8640
# 3.8167166709899902 8704
# 3.982919216156006 8768
# 3.473694324493408 8832
# 4.176309585571289 8896
# 3.8274738788604736 8960
# 3.39308500289917 9024
# 3.968069076538086 9088
# 4.010887622833252 9152
# 4.0050458908081055 9216
# 3.415673017501831 9280
# 3.5286262035369873 9344
# 3.602564811706543 9408
# 3.6513373851776123 9472
# 3.765748977661133 9536
# 3.941180467605591 9600
# 3.570943832397461 9664
# 3.618861436843872 9728
# 3.503385066986084 9792
# 3.7479238510131836 9856
# 3.769645929336548 9920
# 3.6474850177764893 9984
# 3.719538450241089 10048
# 3.446725845336914 10112
# 3.529356002807617 10176
# 3.599205493927002 10240
# 3.4258005619049072 10304
# 4.251768589019775 10368
# 3.617429494857788 10432
# 3.282349109649658 10496
# 4.053537368774414 10560
# 3.711369514465332 10624
# 3.782858371734619 10688
# 3.1081533432006836 10752
# 3.2773971557617188 10816
# 3.9051623344421387 10880
# 4.009951114654541 10944
# 4.167775630950928 11008
# 3.608314037322998 11072
# 3.8339667320251465 11136
# 3.0307416915893555 11200
# 3.3446497917175293 11264
# 3.5845460891723633 11328
# 3.5306432247161865 11392
# 3.626710891723633 11456
# 3.5915603637695312 11520
# 3.5067813396453857 11584
# 3.850532054901123 11648
# 4.6856913566589355 11712
# 3.7581870555877686 11776
# 2.993500232696533 11840
# 3.9773411750793457 11904
# 3.694694995880127 11968
# 3.5705056190490723 12032
# 3.22098970413208 12096
# 4.029873847961426 12160
# 3.50368070602417 12224
# 4.025542259216309 12288
# 4.16064977645874 12352
# 4.29859733581543 12416
# 3.7208595275878906 12480
# 3.953014373779297 12544
# 4.043595314025879 12608
# 3.821528673171997 12672
# 3.3109400272369385 12736
# 3.731393575668335 12800
# 3.7442150115966797 12864
# 3.4815125465393066 12928
# 3.339362382888794 12992
# 3.519775390625 13056
# 3.6744866371154785 13120
# 3.5148894786834717 13184
# 3.469193458557129 13248
# 3.6517629623413086 13312
# 3.592050552368164 13376
# 3.8750832080841064 13440
# 4.763639450073242 13504
# 3.868753433227539 13568
# 4.077157974243164 13632
# 3.579429864883423 13696
# 3.687345504760742 13760
# 3.445404529571533 13824
# 3.8073792457580566 13888
# 4.345470428466797 13952
# 3.097372055053711 14016
# 3.796074867248535 14080
# 3.5752029418945312 14144
# 4.073045253753662 14208
# 3.5113730430603027 14272
# 3.7544236183166504 14336
# 3.321780204772949 14400
# 3.5978803634643555 14464
# 3.821899652481079 14528
# 3.310413360595703 14592
# 3.1667633056640625 14656
# 3.6230618953704834 14720
# 3.6372580528259277 14784
# 3.809333324432373 14848
# 3.673344135284424 14912
# 3.4947526454925537 14976
# 3.7162952423095703 15040
# 3.9890196323394775 15104
# 4.310762405395508 15168
# 4.02052640914917 15232
# 3.4514613151550293 15296
# 4.077241897583008 15360
# 3.7359352111816406 15424
# 3.668267250061035 15488
# 4.032196998596191 15552
# 3.8615963459014893 15616
# 3.7118582725524902 15680
# 4.0872907638549805 15744
# 4.114075660705566 15808
# 3.9629855155944824 15872
# 4.239816665649414 15936
# 3.850587844848633 16000
# 3.9007091522216797 16064
# 3.7344717979431152 16128
# 3.8467469215393066 16192
# 4.47638463973999 16256
# 3.531266212463379 16320
# 4.116021156311035 16384
# 3.740333080291748 16448
# 4.028504371643066 16512
# 3.8093833923339844 16576
# 4.117835998535156 16640
# 3.4401869773864746 16704
# 3.8949320316314697 16768
# 3.0791666507720947 16832
# 3.281447410583496 16896
# 3.4940896034240723 16960
# 3.6928417682647705 17024
# 3.963956594467163 17088
# 3.304248332977295 17152
# 3.6641221046447754 17216
# 4.222225666046143 17280
# 3.82574725151062 17344
# 4.004022598266602 17408
# 3.5180375576019287 17472
# 3.7133607864379883 17536
# 3.9291908740997314 17600
# 3.6936426162719727 17664
# 3.825260877609253 17728
# 3.8999600410461426 17792
# 3.646789312362671 17856
# 4.101528644561768 17920
# 3.622119903564453 17984
# 3.643643856048584 18048
# 3.896575450897217 18112
# 3.8869729042053223 18176
# 4.3148064613342285 18240
# 3.2714858055114746 18304
# 3.2754626274108887 18368
# 3.303520679473877 18432
# 3.5707602500915527 18496
# 4.0953369140625 18560
# 3.660290241241455 18624
# 3.322585105895996 18688
# 3.9025416374206543 18752
# 3.806217908859253 18816
# 3.4843928813934326 18880
# 3.498587131500244 18944
# 4.577266693115234 19008
# 4.127235412597656 19072
# 3.2509407997131348 19136
# 3.575411558151245 19200
# 3.7886834144592285 19264
# 3.3214049339294434 19328
# 3.6865074634552 19392
# 3.582944393157959 19456
# 3.2984461784362793 19520
# 4.13219690322876 19584
# 3.6920976638793945 19648
# 4.177378177642822 19712
# 3.934140205383301 19776
# 3.7706356048583984 19840
# 3.8047165870666504 19904
# 4.0018696784973145 19968
# 4.03685188293457 20032
# 3.3788745403289795 20096
# 3.9045937061309814 20160
# 3.499439001083374 20224
# 3.768235445022583 20288
# 4.002038955688477 20352
# 3.4142675399780273 20416
# 3.66719388961792 20480
# 3.1776814460754395 20544
# 4.047487258911133 20608
# 4.648344993591309 20672
# 3.740935802459717 20736
# 3.50044846534729 20800
# 3.7433104515075684 20864
# 3.4647583961486816 20928
# 3.4348816871643066 20992
# 3.2643344402313232 21056
# 4.234403610229492 21120
# 3.7820231914520264 21184
# 3.8964176177978516 21248
# 3.6822919845581055 21312
# 3.377298355102539 21376
# 3.6246681213378906 21440
# 3.91943359375 21504
# 3.1586880683898926 21568
# 4.136140823364258 21632
# 3.8204104900360107 21696
# 3.8574469089508057 21760
# 3.6493043899536133 21824
# 3.6721291542053223 21888
# 3.527891159057617 21952
# 3.6862354278564453 22016
# 2.98561692237854 22080
# 4.193737983703613 22144
# 3.4951977729797363 22208
# 3.5594072341918945 22272
# 4.04293155670166 22336
# 3.9572362899780273 22400
# 3.734649896621704 22464
# 3.635847568511963 22528
# 3.4406118392944336 22592
# 3.811061382293701 22656
# 3.7631120681762695 22720
# 3.6507139205932617 22784
# 3.7277112007141113 22848
# 3.7411670684814453 22912
# 4.1914777755737305 22976
# 3.9057388305664062 23040
# 3.9282946586608887 23104
# 3.676168203353882 23168
# 3.9731054306030273 23232
# 3.4077651500701904 23296
# 3.7082326412200928 23360
# 3.6105761528015137 23424
# 3.9233531951904297 23488
# 3.785909414291382 23552
# 4.349418640136719 23616
# 3.868239402770996 23680
# 3.8704240322113037 23744
# 3.7933406829833984 23808
# 3.8007988929748535 23872
# 4.314041614532471 23936
# 3.5875394344329834 24000
# 3.6668920516967773 24064
# 3.856320858001709 24128
# 3.9985570907592773 24192
# 3.840524673461914 24256
# 3.69970703125 24320
# 3.44057559967041 24384
# 3.6855125427246094 24448
# 3.3894176483154297 24512
# 3.9660234451293945 24576
# 3.488281011581421 24640
# 3.913849115371704 24704
# 3.6639389991760254 24768
# 3.16925311088562 24832
# 3.700509786605835 24896
# 3.803097724914551 24960
# 3.712198257446289 25024
# 3.6917426586151123 25088
# 3.4627132415771484 25152
# 3.6110949516296387 25216
# 3.7140564918518066 25280
# 4.064506530761719 25344
# 3.640087366104126 25408
# 3.907953977584839 25472
# 3.9144039154052734 25536
# 4.6368560791015625 25600
# 4.003365993499756 25664
# 3.7675113677978516 25728
# 3.737291097640991 25792
# 4.029068470001221 25856
# 3.9637889862060547 25920
# 3.4530296325683594 25984
# 3.4056782722473145 26048
# 3.847989797592163 26112
# 3.4870707988739014 26176
# 3.5140380859375 26240
# 3.353583574295044 26304
# 3.5299339294433594 26368
# 4.644921779632568 26432
# 4.1180315017700195 26496
# 4.0011796951293945 26560
# 3.390111207962036 26624
# 3.7206828594207764 26688
# 3.565612316131592 26752
# 3.3005166053771973 26816
# 3.6501941680908203 26880
# 4.046590805053711 26944
# 3.5799663066864014 27008
# 4.068981170654297 27072
# 3.8514628410339355 27136
# 3.5692474842071533 27200
# 3.510230302810669 27264
# 3.73795747756958 27328
# 3.391859531402588 27392
# 3.3714792728424072 27456
# 3.4604198932647705 27520
# 3.5273208618164062 27584
# 3.827177047729492 27648
# 3.91109037399292 27712
# 3.2891201972961426 27776
# 3.589266777038574 27840
# 3.95764422416687 27904
# 3.6429498195648193 27968
# 3.260972738265991 28032
# 3.96331524848938 28096
# 3.9970340728759766 28160
# 4.077665328979492 28224
# 3.714311122894287 28288
# 3.8990702629089355 28352
# 3.688985824584961 28416
# 3.5606563091278076 28480
# 3.155803680419922 28544
# 3.6633694171905518 28608
# 3.9077134132385254 28672
# 4.231334209442139 28736
# 4.510869026184082 28800
# 3.8566999435424805 28864
# 3.580003499984741 28928
# 3.3887782096862793 28992
# 4.078727722167969 29056
# 3.5859692096710205 29120
# 3.879378318786621 29184
# 3.6243395805358887 29248
# 3.2290854454040527 29312
# 3.33087158203125 29376
# 4.298342227935791 29440
# 4.146724700927734 29504
# 3.66072154045105 29568
# 3.477660655975342 29632
# 3.9767751693725586 29696
# 3.750709056854248 29760
# 3.744051933288574 29824
# 3.627199172973633 29888
# 3.689286231994629 29952
# 3.865210771560669 30016
# 3.916046142578125 30080
# 3.782085418701172 30144
# 3.565609931945801 30208
# 3.9028725624084473 30272
# 3.5932271480560303 30336
# 3.7221083641052246 30400
# 3.1466240882873535 30464
# 3.3407180309295654 30528
# 3.5638227462768555 30592
# 3.8836255073547363 30656
# 4.079895973205566 30720
# 3.643129587173462 30784
# 3.8615105152130127 30848
# 4.037164211273193 30912
# 6.304072380065918 30976
# 3.851732015609741 31040
# 3.458033561706543 31104
# 3.437838554382324 31168
# 3.2058379650115967 31232
# 4.072784423828125 31296
# 3.3617663383483887 31360
# 3.5470268726348877 31424
# 3.4242594242095947 31488
# 3.7162439823150635 31552
# 3.464069128036499 31616
# 3.515455961227417 31680
# 3.9756927490234375 31744
# 3.19174861907959 31808
# 3.845254898071289 31872
# 3.5843825340270996 31936
# 3.5578927993774414 32000
# 3.9993159770965576 32064
# 3.753446578979492 32128
# 3.821136236190796 32192
# 3.8567988872528076 32256
# 3.6188900470733643 32320
# 3.294140338897705 32384
# 3.744246482849121 32448
# 3.450752019882202 32512
# 4.276220798492432 32576
# 4.264258861541748 32640
# 3.874720335006714 32704
# 3.624014377593994 32768
# 4.515097141265869 32832
# 3.9861176013946533 32896
# 3.19697642326355 32960
# 3.3346142768859863 33024
# 4.100867748260498 33088
# 3.742508888244629 33152
# 3.428119659423828 33216
# 2.9643688201904297 33280
# 4.295475959777832 33344
# 3.766597032546997 33408
# 3.5932912826538086 33472
# 3.576334238052368 33536
# 3.562593936920166 33600
# 3.679379463195801 33664
# 4.544534683227539 33728
# 4.172329902648926 33792
# 3.685380220413208 33856
# 3.401855945587158 33920
# 4.0993452072143555 33942
# Epoch: [1/1], Loss: 0.0590

# %%
scores_test = linear_probe.evaluate_probe(probe, X_test, y_test, metric='mse')
print( '[* test score]', scores_test)
# Out:
# Evaluating: 0it [00:00, ?it/s]
# Score (mse) of the probe: 3.77
# [* test score] {'__OVERALL__': 3.7677808}

# %%
scores_test
# Out:
# {'__OVERALL__': 3.7677808}

# %%
0.1154 * 32
# Out:
# 3.6928

# %%
import os
import numpy as np
from tqdm import tqdm

from ttsxai.utils.utils import read_ljs_metadata

# %%
data_activation_dir = "/nas/users/dahye/kw/tts/ttsxai/data_activation/LJSpeech/tacotron2_waveglow"

# Dictionary keys to filter
keys_to_filter = read_ljs_metadata(mode='test')

# List to store filtered paths
npz_files = []

# Iterate over all files in the directory
for file in os.listdir(data_activation_dir):
    # Check only for .npz files
    if file.endswith('.npz'):
        # Extract the identifier part from the file name (e.g., 'LJ037-0213')
        identifier = file.split('.')[0]

        # If this identifier is included in the dictionary keys, add to the list
        if identifier in keys_to_filter:
            full_path = os.path.join(data_activation_dir, file)
            npz_files.append(full_path)

# %%
all_phonesymbols = []
all_articulatory_features = []
all_activations = []
for file in tqdm(npz_files):
    data_dict = np.load(file, allow_pickle=True)
    activations = data_dict['activations'].item()
    
    phonesymbols = data_dict['phonesymbols']
    articulatory_features = data_dict['articulatory_features']

    all_phonesymbols.append(phonesymbols)
    all_articulatory_features.append(articulatory_features)
    all_activations.append(activations)
# Out:
# 100%|██████████| 500/500 [00:01<00:00, 314.62it/s]

# %%
def create_tensors(
    source_tokens,
    target_tokens,
    activations,
    task_specific_tag="Unknown",
    task_type="classification",
    binarized_tag=None,
    balance_data=False,
    dtype=None,
    ignore_tags=None
):
    """
    Method to pre-process loaded datasets into tensors that can be used to train
    probes and perform analyis on. The input tokens are represented as list of
    sentences, where each sentence is a list of tokens. Each token also has
    an associated label. All tokens from all sentences are flattened into one
    dimension in the returned tensors. The returned tensors will thus have
    ``total_num_tokens`` rows.

    Parameters
    ----------
    source_tokens: list of arrays
        List of sentences, where each sentence is a list of tokens. 
        e.g., [array(['M', 'ER0', 'IY1', ...], array(['JH', 'AH1', 'S', ...])
    target_tokens: list of arrays
        It depends on task_type. For example, in classification task, 
        articulatory_features can be used as targets.
        e.g., [['Bilabial', 'Vowel', 'Vowel', ...], [...]]
    activations : list of dictionary
        e.g., activations[0] has
        {'conv_0': ..., 'conv_1': ...}
        where each key has *sentence representations*, where each *sentence representation*
        is a numpy matrix of shape.
    task_specific_tag : str
        Label to assign tokens with unseen labels. This is particularly useful
        if some labels are never seen during train, but are present in the dev
        or test set. This is usually set to the majority class in the task.
    task_type : str
        Either "classification" or "regression", indicate the kind of task that
        is being probed.
    binarized_tag : str, optional
            Tag/Label to create binary data. All other labels in the dataset are changed
            to OTHER. Defaults to None in which case the data labels are processed as-is.
    balance_data : bool, optional
        Whether the incoming data should be balanced. Data is balanced using
        utils.balance_binary_class_data for binary data and utils.balance_multi_class_data
        for multi-class data using undersampling. Defaults to False.
    dtype : str, optional
        None if the dtype of the activation tensor should be the same dtype as in the activations input
        e.g. 'float16' or 'float32' to enforce half-precision or full-precision floats

    """
    assert (
        task_type == "classification" or task_type == "regression"
    ), "Invalid model type"

    if ignore_tags is None:
        ignore_tags = []

    filtered_source_tokens = []
    filtered_target_tokens = []

    for source_sentence, target_sentence in zip(source_tokens, target_tokens):
        filtered_source_sentence = []
        filtered_target_sentence = []
        for source_token, target_token in zip(source_sentence, target_sentence):
            if target_token not in ignore_tags:
                filtered_source_sentence.append(source_token)
                filtered_target_sentence.append(target_token)
        filtered_source_tokens.append(np.array(filtered_source_sentence))
        filtered_target_tokens.append(np.array(filtered_target_sentence))

    source_tokens = filtered_source_tokens
    target_tokens = filtered_target_tokens

    num_tokens = count_tokens(source_tokens)
    print("Number of tokens: ", num_tokens)

    # Concatenate activations
    concatenated_activations = [np.concatenate(list(d.values()), axis=1) for d in activations]
    num_neurons = concatenated_activations[0].shape[1]

    if task_type == "classification":
        if binarized_tag:
            label2idx = {binarized_tag: 1, "OTHER": 0}
            idx2label = {1: binarized_tag, 0: "OTHER"}
        else:
            label2idx = tok2idx(target_tokens)
            idx2label = idx2tok(label2idx)

    src2idx = tok2idx(source_tokens)
    idx2src = idx2tok(src2idx)
    nidx2name = neuronidx2name(activations[0])

    print("length of source dictionary: ", len(src2idx))
    if task_type == "classification":
        print("length of target dictionary: ", len(label2idx))

    if dtype == None:
        dtype = concatenated_activations[0].dtype
    X = np.zeros((num_tokens, num_neurons), dtype=dtype)
    if task_type == "classification":
        y = np.zeros((num_tokens,), dtype=np.int)
    else:
        y = np.zeros((num_tokens,), dtype=np.float32)

    example_set = set()

    idx = 0
    for instance_idx, instance in enumerate(target_tokens):
        for token_idx, _ in enumerate(instance):
            if idx < num_tokens:
                X[idx] = concatenated_activations[instance_idx][token_idx, :]

            example_set.add(source_tokens[instance_idx][token_idx])
            if task_type == "classification":
                current_target_token = target_tokens[instance_idx][token_idx]
                if binarized_tag and current_target_token != binarized_tag:
                    current_target_token = "OTHER"
                y[idx] = label2idx[current_target_token]
            elif task_type == "regression":
                y[idx] = float(target_tokens[instance_idx][token_idx])

            idx += 1

    print(idx)
    print("Total instances: %d" % (num_tokens))
    # print(list(example_set)[:20])
    print(list(example_set))

    print("Number of samples: ", X.shape[0])

    # if balance_data:
    #     print("Balancing data ... ")
    #     if binarized_tag:
    #         X, y = balance_binary_class_data(X, y)
    #     else:
    #         X, y = balance_multi_class_data(X, y)
    #     print("Number of samples after balancing: ", X.shape[0])

    labels, freqs = np.unique(y, return_counts=True)

    print("Stats: Labels with their frequencies in the final set")
    for idx, label in enumerate(labels):
        print(idx2label[label], freqs[idx])

    if task_type == "classification":
        return X, y, (label2idx, idx2label, src2idx, idx2src, nidx2name)
    return X, y, (src2idx, idx2src)


def count_tokens(source):
    """
    Utility function to count the total number of tokens in a dataset.
    """
    return sum([len(t) for t in source])


def tok2idx(tokens):
    """
    Utility function to generate unique indices for a set of tokens.
    """
    uniq_tokens = set().union(*tokens)
    return {p: idx for idx, p in enumerate(uniq_tokens)}


def idx2tok(srcidx):
    """
    Utility function to an inverse mapping from a ``tok2idx`` mapping.
    """
    return {v: k for k, v in srcidx.items()}


# Create the mapping for a single activation dictionary
def neuronidx2name(d):
    mapping = {}
    current_start_index = 0
    for layer_name, activations in d.items():
        # Calculate the end index for this activation
        end_index = current_start_index + activations.shape[1] - 1
        for i in range(current_start_index, end_index + 1):
            mapping[i] = f'{layer_name}__{i - current_start_index}'
        current_start_index = end_index + 1
    return mapping


X, y, mapping = create_tensors(
    all_phonesymbols,
    all_articulatory_features,
    all_activations,
    task_type='classification',
    # ignore_tags=['Space', 'Punctuation']
)
# Out:
# Number of tokens:  43250
# length of source dictionary:  78
# length of target dictionary:  12
# /home/dahye/anaconda3/envs/ttsxai/lib/python3.7/site-packages/ipykernel_launcher.py:103: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 43250
# Total instances: 43250
# ['ZH', 'ER2', 'NG', 'P', 'IY2', 'AA2', 'OY2', 'UH2', 'AW1', 'EH1', 'AO1', 'W', 'EY1', 'UH0', 'AO0', 'Y', 'AY2', 'N', 'AA0', 'UW2', 'S', "'", 'Z', 'CH', 'UW0', 'TH', ' ', 'OW1', 'OY1', 'IH2', 'AA1', 'UH1', 'SH', '(', 'IY1', 'AW2', 'ER1', 'G', 'D', 'UW1', ')', 'AE0', 'OW0', 'OW2', '.', 'IH0', 'EY0', ':', 'IH1', 'V', 'F', '-', ',', 'AH2', 'AE2', ';', 'AE1', 'EH0', 'AY0', 'AY1', 'JH', 'EH2', 'AH0', 'T', 'IY0', 'L', 'B', 'R', 'AO2', 'EY2', 'AW0', 'DH', 'HH', 'M', 'K', 'AH1', 'ER0', '?']
# Number of samples:  43250
# Stats: Labels with their frequencies in the final set
# Dental 1302
# Labio-Velar 790
# Palatal 184
# Labiodental 1411
# Vowel 13305
# Punctuation 1016
# Alveolar 12338
# Post-Alveolar 660
# Bilabial 2225
# Velar 1503
# Space 7989
# Glottal 527

# %%
mapping
# Out:
# ({'Dental': 0,
#   'Labio-Velar': 1,
#   'Palatal': 2,
#   'Labiodental': 3,
#   'Vowel': 4,
#   'Punctuation': 5,
#   'Alveolar': 6,
#   'Post-Alveolar': 7,
#   'Bilabial': 8,
#   'Velar': 9,
#   'Space': 10,
#   'Glottal': 11},
#  {0: 'Dental',
#   1: 'Labio-Velar',
#   2: 'Palatal',
#   3: 'Labiodental',
#   4: 'Vowel',
#   5: 'Punctuation',
#   6: 'Alveolar',
#   7: 'Post-Alveolar',
#   8: 'Bilabial',
#   9: 'Velar',
#   10: 'Space',
#   11: 'Glottal'},
#  {'ZH': 0,
#   'ER2': 1,
#   'NG': 2,
#   'P': 3,
#   'IY2': 4,
#   'AA2': 5,
#   'OY2': 6,
#   'UH2': 7,
#   'AW1': 8,
#   'EH1': 9,
#   'AO1': 10,
#   'W': 11,
#   'EY1': 12,
#   'UH0': 13,
#   'AO0': 14,
#   'Y': 15,
#   'AY2': 16,
#   'N': 17,
#   'AA0': 18,
#   'UW2': 19,
#   'S': 20,
#   "'": 21,
#   'Z': 22,
#   'CH': 23,
#   'UW0': 24,
#   'TH': 25,
#   ' ': 26,
#   'OW1': 27,
#   'OY1': 28,
#   'IH2': 29,
#   'AA1': 30,
#   'UH1': 31,
#   'SH': 32,
#   '(': 33,
#   'IY1': 34,
#   'AW2': 35,
#   'ER1': 36,
#   'G': 37,
#   'D': 38,
#   'UW1': 39,
#   ')': 40,
#   'AE0': 41,
#   'OW0': 42,
#   'OW2': 43,
#   '.': 44,
#   'IH0': 45,
#   'EY0': 46,
#   ':': 47,
#   'IH1': 48,
#   'V': 49,
#   'F': 50,
#   '-': 51,
#   ',': 52,
#   'AH2': 53,
#   'AE2': 54,
#   ';': 55,
#   'AE1': 56,
#   'EH0': 57,
#   'AY0': 58,
#   'AY1': 59,
#   'JH': 60,
#   'EH2': 61,
#   'AH0': 62,
#   'T': 63,
#   'IY0': 64,
#   'L': 65,
#   'B': 66,
#   'R': 67,
#   'AO2': 68,
#   'EY2': 69,
#   'AW0': 70,
#   'DH': 71,
#   'HH': 72,
#   'M': 73,
#   'K': 74,
#   'AH1': 75,
#   'ER0': 76,
#   '?': 77},
#  {0: 'ZH',
#   1: 'ER2',
#   2: 'NG',
#   3: 'P',
#   4: 'IY2',
#   5: 'AA2',
#   6: 'OY2',
#   7: 'UH2',
#   8: 'AW1',
#   9: 'EH1',
#   10: 'AO1',
#   11: 'W',
#   12: 'EY1',
#   13: 'UH0',
#   14: 'AO0',
#   15: 'Y',
#   16: 'AY2',
#   17: 'N',
#   18: 'AA0',
#   19: 'UW2',
#   20: 'S',
#   21: "'",
#   22: 'Z',
#   23: 'CH',
#   24: 'UW0',
#   25: 'TH',
#   26: ' ',
#   27: 'OW1',
#   28: 'OY1',
#   29: 'IH2',
#   30: 'AA1',
#   31: 'UH1',
#   32: 'SH',
#   33: '(',
#   34: 'IY1',
#   35: 'AW2',
#   36: 'ER1',
#   37: 'G',
#   38: 'D',
#   39: 'UW1',
#   40: ')',
#   41: 'AE0',
#   42: 'OW0',
#   43: 'OW2',
#   44: '.',
#   45: 'IH0',
#   46: 'EY0',
#   47: ':',
#   48: 'IH1',
#   49: 'V',
#   50: 'F',
#   51: '-',
#   52: ',',
#   53: 'AH2',
#   54: 'AE2',
#   55: ';',
#   56: 'AE1',
#   57: 'EH0',
#   58: 'AY0',
#   59: 'AY1',
#   60: 'JH',
#   61: 'EH2',
#   62: 'AH0',
#   63: 'T',
#   64: 'IY0',
#   65: 'L',
#   66: 'B',
#   67: 'R',
#   68: 'AO2',
#   69: 'EY2',
#   70: 'AW0',
#   71: 'DH',
#   72: 'HH',
#   73: 'M',
#   74: 'K',
#   75: 'AH1',
#   76: 'ER0',
#   77: '?'},
#  {0: 'conv_0__0',
#   1: 'conv_0__1',
#   2: 'conv_0__2',
#   3: 'conv_0__3',
#   4: 'conv_0__4',
#   5: 'conv_0__5',
#   6: 'conv_0__6',
#   7: 'conv_0__7',
#   8: 'conv_0__8',
#   9: 'conv_0__9',
#   10: 'conv_0__10',
#   11: 'conv_0__11',
#   12: 'conv_0__12',
#   13: 'conv_0__13',
#   14: 'conv_0__14',
#   15: 'conv_0__15',
#   16: 'conv_0__16',
#   17: 'conv_0__17',
#   18: 'conv_0__18',
#   19: 'conv_0__19',
#   20: 'conv_0__20',
#   21: 'conv_0__21',
#   22: 'conv_0__22',
#   23: 'conv_0__23',
#   24: 'conv_0__24',
#   25: 'conv_0__25',
#   26: 'conv_0__26',
#   27: 'conv_0__27',
#   28: 'conv_0__28',
#   29: 'conv_0__29',
#   30: 'conv_0__30',
#   31: 'conv_0__31',
#   32: 'conv_0__32',
#   33: 'conv_0__33',
#   34: 'conv_0__34',
#   35: 'conv_0__35',
#   36: 'conv_0__36',
#   37: 'conv_0__37',
#   38: 'conv_0__38',
#   39: 'conv_0__39',
#   40: 'conv_0__40',
#   41: 'conv_0__41',
#   42: 'conv_0__42',
#   43: 'conv_0__43',
#   44: 'conv_0__44',
#   45: 'conv_0__45',
#   46: 'conv_0__46',
#   47: 'conv_0__47',
#   48: 'conv_0__48',
#   49: 'conv_0__49',
#   50: 'conv_0__50',
#   51: 'conv_0__51',
#   52: 'conv_0__52',
#   53: 'conv_0__53',
#   54: 'conv_0__54',
#   55: 'conv_0__55',
#   56: 'conv_0__56',
#   57: 'conv_0__57',
#   58: 'conv_0__58',
#   59: 'conv_0__59',
#   60: 'conv_0__60',
#   61: 'conv_0__61',
#   62: 'conv_0__62',
#   63: 'conv_0__63',
#   64: 'conv_0__64',
#   65: 'conv_0__65',
#   66: 'conv_0__66',
#   67: 'conv_0__67',
#   68: 'conv_0__68',
#   69: 'conv_0__69',
#   70: 'conv_0__70',
#   71: 'conv_0__71',
#   72: 'conv_0__72',
#   73: 'conv_0__73',
#   74: 'conv_0__74',
#   75: 'conv_0__75',
#   76: 'conv_0__76',
#   77: 'conv_0__77',
#   78: 'conv_0__78',
#   79: 'conv_0__79',
#   80: 'conv_0__80',
#   81: 'conv_0__81',
#   82: 'conv_0__82',
#   83: 'conv_0__83',
#   84: 'conv_0__84',
#   85: 'conv_0__85',
#   86: 'conv_0__86',
#   87: 'conv_0__87',
#   88: 'conv_0__88',
#   89: 'conv_0__89',
#   90: 'conv_0__90',
#   91: 'conv_0__91',
#   92: 'conv_0__92',
#   93: 'conv_0__93',
#   94: 'conv_0__94',
#   95: 'conv_0__95',
#   96: 'conv_0__96',
#   97: 'conv_0__97',
#   98: 'conv_0__98',
#   99: 'conv_0__99',
#   100: 'conv_0__100',
#   101: 'conv_0__101',
#   102: 'conv_0__102',
#   103: 'conv_0__103',
#   104: 'conv_0__104',
#   105: 'conv_0__105',
#   106: 'conv_0__106',
#   107: 'conv_0__107',
#   108: 'conv_0__108',
#   109: 'conv_0__109',
#   110: 'conv_0__110',
#   111: 'conv_0__111',
#   112: 'conv_0__112',
#   113: 'conv_0__113',
#   114: 'conv_0__114',
#   115: 'conv_0__115',
#   116: 'conv_0__116',
#   117: 'conv_0__117',
#   118: 'conv_0__118',
#   119: 'conv_0__119',
#   120: 'conv_0__120',
#   121: 'conv_0__121',
#   122: 'conv_0__122',
#   123: 'conv_0__123',
#   124: 'conv_0__124',
#   125: 'conv_0__125',
#   126: 'conv_0__126',
#   127: 'conv_0__127',
#   128: 'conv_0__128',
#   129: 'conv_0__129',
#   130: 'conv_0__130',
#   131: 'conv_0__131',
#   132: 'conv_0__132',
#   133: 'conv_0__133',
#   134: 'conv_0__134',
#   135: 'conv_0__135',
#   136: 'conv_0__136',
#   137: 'conv_0__137',
#   138: 'conv_0__138',
#   139: 'conv_0__139',
#   140: 'conv_0__140',
#   141: 'conv_0__141',
#   142: 'conv_0__142',
#   143: 'conv_0__143',
#   144: 'conv_0__144',
#   145: 'conv_0__145',
#   146: 'conv_0__146',
#   147: 'conv_0__147',
#   148: 'conv_0__148',
#   149: 'conv_0__149',
#   150: 'conv_0__150',
#   151: 'conv_0__151',
#   152: 'conv_0__152',
#   153: 'conv_0__153',
#   154: 'conv_0__154',
#   155: 'conv_0__155',
#   156: 'conv_0__156',
#   157: 'conv_0__157',
#   158: 'conv_0__158',
#   159: 'conv_0__159',
#   160: 'conv_0__160',
#   161: 'conv_0__161',
#   162: 'conv_0__162',
#   163: 'conv_0__163',
#   164: 'conv_0__164',
#   165: 'conv_0__165',
#   166: 'conv_0__166',
#   167: 'conv_0__167',
#   168: 'conv_0__168',
#   169: 'conv_0__169',
#   170: 'conv_0__170',
#   171: 'conv_0__171',
#   172: 'conv_0__172',
#   173: 'conv_0__173',
#   174: 'conv_0__174',
#   175: 'conv_0__175',
#   176: 'conv_0__176',
#   177: 'conv_0__177',
#   178: 'conv_0__178',
#   179: 'conv_0__179',
#   180: 'conv_0__180',
#   181: 'conv_0__181',
#   182: 'conv_0__182',
#   183: 'conv_0__183',
#   184: 'conv_0__184',
#   185: 'conv_0__185',
#   186: 'conv_0__186',
#   187: 'conv_0__187',
#   188: 'conv_0__188',
#   189: 'conv_0__189',
#   190: 'conv_0__190',
#   191: 'conv_0__191',
#   192: 'conv_0__192',
#   193: 'conv_0__193',
#   194: 'conv_0__194',
#   195: 'conv_0__195',
#   196: 'conv_0__196',
#   197: 'conv_0__197',
#   198: 'conv_0__198',
#   199: 'conv_0__199',
#   200: 'conv_0__200',
#   201: 'conv_0__201',
#   202: 'conv_0__202',
#   203: 'conv_0__203',
#   204: 'conv_0__204',
#   205: 'conv_0__205',
#   206: 'conv_0__206',
#   207: 'conv_0__207',
#   208: 'conv_0__208',
#   209: 'conv_0__209',
#   210: 'conv_0__210',
#   211: 'conv_0__211',
#   212: 'conv_0__212',
#   213: 'conv_0__213',
#   214: 'conv_0__214',
#   215: 'conv_0__215',
#   216: 'conv_0__216',
#   217: 'conv_0__217',
#   218: 'conv_0__218',
#   219: 'conv_0__219',
#   220: 'conv_0__220',
#   221: 'conv_0__221',
#   222: 'conv_0__222',
#   223: 'conv_0__223',
#   224: 'conv_0__224',
#   225: 'conv_0__225',
#   226: 'conv_0__226',
#   227: 'conv_0__227',
#   228: 'conv_0__228',
#   229: 'conv_0__229',
#   230: 'conv_0__230',
#   231: 'conv_0__231',
#   232: 'conv_0__232',
#   233: 'conv_0__233',
#   234: 'conv_0__234',
#   235: 'conv_0__235',
#   236: 'conv_0__236',
#   237: 'conv_0__237',
#   238: 'conv_0__238',
#   239: 'conv_0__239',
#   240: 'conv_0__240',
#   241: 'conv_0__241',
#   242: 'conv_0__242',
#   243: 'conv_0__243',
#   244: 'conv_0__244',
#   245: 'conv_0__245',
#   246: 'conv_0__246',
#   247: 'conv_0__247',
#   248: 'conv_0__248',
#   249: 'conv_0__249',
#   250: 'conv_0__250',
#   251: 'conv_0__251',
#   252: 'conv_0__252',
#   253: 'conv_0__253',
#   254: 'conv_0__254',
#   255: 'conv_0__255',
#   256: 'conv_0__256',
#   257: 'conv_0__257',
#   258: 'conv_0__258',
#   259: 'conv_0__259',
#   260: 'conv_0__260',
#   261: 'conv_0__261',
#   262: 'conv_0__262',
#   263: 'conv_0__263',
#   264: 'conv_0__264',
#   265: 'conv_0__265',
#   266: 'conv_0__266',
#   267: 'conv_0__267',
#   268: 'conv_0__268',
#   269: 'conv_0__269',
#   270: 'conv_0__270',
#   271: 'conv_0__271',
#   272: 'conv_0__272',
#   273: 'conv_0__273',
#   274: 'conv_0__274',
#   275: 'conv_0__275',
#   276: 'conv_0__276',
#   277: 'conv_0__277',
#   278: 'conv_0__278',
#   279: 'conv_0__279',
#   280: 'conv_0__280',
#   281: 'conv_0__281',
#   282: 'conv_0__282',
#   283: 'conv_0__283',
#   284: 'conv_0__284',
#   285: 'conv_0__285',
#   286: 'conv_0__286',
#   287: 'conv_0__287',
#   288: 'conv_0__288',
#   289: 'conv_0__289',
#   290: 'conv_0__290',
#   291: 'conv_0__291',
#   292: 'conv_0__292',
#   293: 'conv_0__293',
#   294: 'conv_0__294',
#   295: 'conv_0__295',
#   296: 'conv_0__296',
#   297: 'conv_0__297',
#   298: 'conv_0__298',
#   299: 'conv_0__299',
#   300: 'conv_0__300',
#   301: 'conv_0__301',
#   302: 'conv_0__302',
#   303: 'conv_0__303',
#   304: 'conv_0__304',
#   305: 'conv_0__305',
#   306: 'conv_0__306',
#   307: 'conv_0__307',
#   308: 'conv_0__308',
#   309: 'conv_0__309',
#   310: 'conv_0__310',
#   311: 'conv_0__311',
#   312: 'conv_0__312',
#   313: 'conv_0__313',
#   314: 'conv_0__314',
#   315: 'conv_0__315',
#   316: 'conv_0__316',
#   317: 'conv_0__317',
#   318: 'conv_0__318',
#   319: 'conv_0__319',
#   320: 'conv_0__320',
#   321: 'conv_0__321',
#   322: 'conv_0__322',
#   323: 'conv_0__323',
#   324: 'conv_0__324',
#   325: 'conv_0__325',
#   326: 'conv_0__326',
#   327: 'conv_0__327',
#   328: 'conv_0__328',
#   329: 'conv_0__329',
#   330: 'conv_0__330',
#   331: 'conv_0__331',
#   332: 'conv_0__332',
#   333: 'conv_0__333',
#   334: 'conv_0__334',
#   335: 'conv_0__335',
#   336: 'conv_0__336',
#   337: 'conv_0__337',
#   338: 'conv_0__338',
#   339: 'conv_0__339',
#   340: 'conv_0__340',
#   341: 'conv_0__341',
#   342: 'conv_0__342',
#   343: 'conv_0__343',
#   344: 'conv_0__344',
#   345: 'conv_0__345',
#   346: 'conv_0__346',
#   347: 'conv_0__347',
#   348: 'conv_0__348',
#   349: 'conv_0__349',
#   350: 'conv_0__350',
#   351: 'conv_0__351',
#   352: 'conv_0__352',
#   353: 'conv_0__353',
#   354: 'conv_0__354',
#   355: 'conv_0__355',
#   356: 'conv_0__356',
#   357: 'conv_0__357',
#   358: 'conv_0__358',
#   359: 'conv_0__359',
#   360: 'conv_0__360',
#   361: 'conv_0__361',
#   362: 'conv_0__362',
#   363: 'conv_0__363',
#   364: 'conv_0__364',
#   365: 'conv_0__365',
#   366: 'conv_0__366',
#   367: 'conv_0__367',
#   368: 'conv_0__368',
#   369: 'conv_0__369',
#   370: 'conv_0__370',
#   371: 'conv_0__371',
#   372: 'conv_0__372',
#   373: 'conv_0__373',
#   374: 'conv_0__374',
#   375: 'conv_0__375',
#   376: 'conv_0__376',
#   377: 'conv_0__377',
#   378: 'conv_0__378',
#   379: 'conv_0__379',
#   380: 'conv_0__380',
#   381: 'conv_0__381',
#   382: 'conv_0__382',
#   383: 'conv_0__383',
#   384: 'conv_0__384',
#   385: 'conv_0__385',
#   386: 'conv_0__386',
#   387: 'conv_0__387',
#   388: 'conv_0__388',
#   389: 'conv_0__389',
#   390: 'conv_0__390',
#   391: 'conv_0__391',
#   392: 'conv_0__392',
#   393: 'conv_0__393',
#   394: 'conv_0__394',
#   395: 'conv_0__395',
#   396: 'conv_0__396',
#   397: 'conv_0__397',
#   398: 'conv_0__398',
#   399: 'conv_0__399',
#   400: 'conv_0__400',
#   401: 'conv_0__401',
#   402: 'conv_0__402',
#   403: 'conv_0__403',
#   404: 'conv_0__404',
#   405: 'conv_0__405',
#   406: 'conv_0__406',
#   407: 'conv_0__407',
#   408: 'conv_0__408',
#   409: 'conv_0__409',
#   410: 'conv_0__410',
#   411: 'conv_0__411',
#   412: 'conv_0__412',
#   413: 'conv_0__413',
#   414: 'conv_0__414',
#   415: 'conv_0__415',
#   416: 'conv_0__416',
#   417: 'conv_0__417',
#   418: 'conv_0__418',
#   419: 'conv_0__419',
#   420: 'conv_0__420',
#   421: 'conv_0__421',
#   422: 'conv_0__422',
#   423: 'conv_0__423',
#   424: 'conv_0__424',
#   425: 'conv_0__425',
#   426: 'conv_0__426',
#   427: 'conv_0__427',
#   428: 'conv_0__428',
#   429: 'conv_0__429',
#   430: 'conv_0__430',
#   431: 'conv_0__431',
#   432: 'conv_0__432',
#   433: 'conv_0__433',
#   434: 'conv_0__434',
#   435: 'conv_0__435',
#   436: 'conv_0__436',
#   437: 'conv_0__437',
#   438: 'conv_0__438',
#   439: 'conv_0__439',
#   440: 'conv_0__440',
#   441: 'conv_0__441',
#   442: 'conv_0__442',
#   443: 'conv_0__443',
#   444: 'conv_0__444',
#   445: 'conv_0__445',
#   446: 'conv_0__446',
#   447: 'conv_0__447',
#   448: 'conv_0__448',
#   449: 'conv_0__449',
#   450: 'conv_0__450',
#   451: 'conv_0__451',
#   452: 'conv_0__452',
#   453: 'conv_0__453',
#   454: 'conv_0__454',
#   455: 'conv_0__455',
#   456: 'conv_0__456',
#   457: 'conv_0__457',
#   458: 'conv_0__458',
#   459: 'conv_0__459',
#   460: 'conv_0__460',
#   461: 'conv_0__461',
#   462: 'conv_0__462',
#   463: 'conv_0__463',
#   464: 'conv_0__464',
#   465: 'conv_0__465',
#   466: 'conv_0__466',
#   467: 'conv_0__467',
#   468: 'conv_0__468',
#   469: 'conv_0__469',
#   470: 'conv_0__470',
#   471: 'conv_0__471',
#   472: 'conv_0__472',
#   473: 'conv_0__473',
#   474: 'conv_0__474',
#   475: 'conv_0__475',
#   476: 'conv_0__476',
#   477: 'conv_0__477',
#   478: 'conv_0__478',
#   479: 'conv_0__479',
#   480: 'conv_0__480',
#   481: 'conv_0__481',
#   482: 'conv_0__482',
#   483: 'conv_0__483',
#   484: 'conv_0__484',
#   485: 'conv_0__485',
#   486: 'conv_0__486',
#   487: 'conv_0__487',
#   488: 'conv_0__488',
#   489: 'conv_0__489',
#   490: 'conv_0__490',
#   491: 'conv_0__491',
#   492: 'conv_0__492',
#   493: 'conv_0__493',
#   494: 'conv_0__494',
#   495: 'conv_0__495',
#   496: 'conv_0__496',
#   497: 'conv_0__497',
#   498: 'conv_0__498',
#   499: 'conv_0__499',
#   500: 'conv_0__500',
#   501: 'conv_0__501',
#   502: 'conv_0__502',
#   503: 'conv_0__503',
#   504: 'conv_0__504',
#   505: 'conv_0__505',
#   506: 'conv_0__506',
#   507: 'conv_0__507',
#   508: 'conv_0__508',
#   509: 'conv_0__509',
#   510: 'conv_0__510',
#   511: 'conv_0__511',
#   512: 'conv_1__0',
#   513: 'conv_1__1',
#   514: 'conv_1__2',
#   515: 'conv_1__3',
#   516: 'conv_1__4',
#   517: 'conv_1__5',
#   518: 'conv_1__6',
#   519: 'conv_1__7',
#   520: 'conv_1__8',
#   521: 'conv_1__9',
#   522: 'conv_1__10',
#   523: 'conv_1__11',
#   524: 'conv_1__12',
#   525: 'conv_1__13',
#   526: 'conv_1__14',
#   527: 'conv_1__15',
#   528: 'conv_1__16',
#   529: 'conv_1__17',
#   530: 'conv_1__18',
#   531: 'conv_1__19',
#   532: 'conv_1__20',
#   533: 'conv_1__21',
#   534: 'conv_1__22',
#   535: 'conv_1__23',
#   536: 'conv_1__24',
#   537: 'conv_1__25',
#   538: 'conv_1__26',
#   539: 'conv_1__27',
#   540: 'conv_1__28',
#   541: 'conv_1__29',
#   542: 'conv_1__30',
#   543: 'conv_1__31',
#   544: 'conv_1__32',
#   545: 'conv_1__33',
#   546: 'conv_1__34',
#   547: 'conv_1__35',
#   548: 'conv_1__36',
#   549: 'conv_1__37',
#   550: 'conv_1__38',
#   551: 'conv_1__39',
#   552: 'conv_1__40',
#   553: 'conv_1__41',
#   554: 'conv_1__42',
#   555: 'conv_1__43',
#   556: 'conv_1__44',
#   557: 'conv_1__45',
#   558: 'conv_1__46',
#   559: 'conv_1__47',
#   560: 'conv_1__48',
#   561: 'conv_1__49',
#   562: 'conv_1__50',
#   563: 'conv_1__51',
#   564: 'conv_1__52',
#   565: 'conv_1__53',
#   566: 'conv_1__54',
#   567: 'conv_1__55',
#   568: 'conv_1__56',
#   569: 'conv_1__57',
#   570: 'conv_1__58',
#   571: 'conv_1__59',
#   572: 'conv_1__60',
#   573: 'conv_1__61',
#   574: 'conv_1__62',
#   575: 'conv_1__63',
#   576: 'conv_1__64',
#   577: 'conv_1__65',
#   578: 'conv_1__66',
#   579: 'conv_1__67',
#   580: 'conv_1__68',
#   581: 'conv_1__69',
#   582: 'conv_1__70',
#   583: 'conv_1__71',
#   584: 'conv_1__72',
#   585: 'conv_1__73',
#   586: 'conv_1__74',
#   587: 'conv_1__75',
#   588: 'conv_1__76',
#   589: 'conv_1__77',
#   590: 'conv_1__78',
#   591: 'conv_1__79',
#   592: 'conv_1__80',
#   593: 'conv_1__81',
#   594: 'conv_1__82',
#   595: 'conv_1__83',
#   596: 'conv_1__84',
#   597: 'conv_1__85',
#   598: 'conv_1__86',
#   599: 'conv_1__87',
#   600: 'conv_1__88',
#   601: 'conv_1__89',
#   602: 'conv_1__90',
#   603: 'conv_1__91',
#   604: 'conv_1__92',
#   605: 'conv_1__93',
#   606: 'conv_1__94',
#   607: 'conv_1__95',
#   608: 'conv_1__96',
#   609: 'conv_1__97',
#   610: 'conv_1__98',
#   611: 'conv_1__99',
#   612: 'conv_1__100',
#   613: 'conv_1__101',
#   614: 'conv_1__102',
#   615: 'conv_1__103',
#   616: 'conv_1__104',
#   617: 'conv_1__105',
#   618: 'conv_1__106',
#   619: 'conv_1__107',
#   620: 'conv_1__108',
#   621: 'conv_1__109',
#   622: 'conv_1__110',
#   623: 'conv_1__111',
#   624: 'conv_1__112',
#   625: 'conv_1__113',
#   626: 'conv_1__114',
#   627: 'conv_1__115',
#   628: 'conv_1__116',
#   629: 'conv_1__117',
#   630: 'conv_1__118',
#   631: 'conv_1__119',
#   632: 'conv_1__120',
#   633: 'conv_1__121',
#   634: 'conv_1__122',
#   635: 'conv_1__123',
#   636: 'conv_1__124',
#   637: 'conv_1__125',
#   638: 'conv_1__126',
#   639: 'conv_1__127',
#   640: 'conv_1__128',
#   641: 'conv_1__129',
#   642: 'conv_1__130',
#   643: 'conv_1__131',
#   644: 'conv_1__132',
#   645: 'conv_1__133',
#   646: 'conv_1__134',
#   647: 'conv_1__135',
#   648: 'conv_1__136',
#   649: 'conv_1__137',
#   650: 'conv_1__138',
#   651: 'conv_1__139',
#   652: 'conv_1__140',
#   653: 'conv_1__141',
#   654: 'conv_1__142',
#   655: 'conv_1__143',
#   656: 'conv_1__144',
#   657: 'conv_1__145',
#   658: 'conv_1__146',
#   659: 'conv_1__147',
#   660: 'conv_1__148',
#   661: 'conv_1__149',
#   662: 'conv_1__150',
#   663: 'conv_1__151',
#   664: 'conv_1__152',
#   665: 'conv_1__153',
#   666: 'conv_1__154',
#   667: 'conv_1__155',
#   668: 'conv_1__156',
#   669: 'conv_1__157',
#   670: 'conv_1__158',
#   671: 'conv_1__159',
#   672: 'conv_1__160',
#   673: 'conv_1__161',
#   674: 'conv_1__162',
#   675: 'conv_1__163',
#   676: 'conv_1__164',
#   677: 'conv_1__165',
#   678: 'conv_1__166',
#   679: 'conv_1__167',
#   680: 'conv_1__168',
#   681: 'conv_1__169',
#   682: 'conv_1__170',
#   683: 'conv_1__171',
#   684: 'conv_1__172',
#   685: 'conv_1__173',
#   686: 'conv_1__174',
#   687: 'conv_1__175',
#   688: 'conv_1__176',
#   689: 'conv_1__177',
#   690: 'conv_1__178',
#   691: 'conv_1__179',
#   692: 'conv_1__180',
#   693: 'conv_1__181',
#   694: 'conv_1__182',
#   695: 'conv_1__183',
#   696: 'conv_1__184',
#   697: 'conv_1__185',
#   698: 'conv_1__186',
#   699: 'conv_1__187',
#   700: 'conv_1__188',
#   701: 'conv_1__189',
#   702: 'conv_1__190',
#   703: 'conv_1__191',
#   704: 'conv_1__192',
#   705: 'conv_1__193',
#   706: 'conv_1__194',
#   707: 'conv_1__195',
#   708: 'conv_1__196',
#   709: 'conv_1__197',
#   710: 'conv_1__198',
#   711: 'conv_1__199',
#   712: 'conv_1__200',
#   713: 'conv_1__201',
#   714: 'conv_1__202',
#   715: 'conv_1__203',
#   716: 'conv_1__204',
#   717: 'conv_1__205',
#   718: 'conv_1__206',
#   719: 'conv_1__207',
#   720: 'conv_1__208',
#   721: 'conv_1__209',
#   722: 'conv_1__210',
#   723: 'conv_1__211',
#   724: 'conv_1__212',
#   725: 'conv_1__213',
#   726: 'conv_1__214',
#   727: 'conv_1__215',
#   728: 'conv_1__216',
#   729: 'conv_1__217',
#   730: 'conv_1__218',
#   731: 'conv_1__219',
#   732: 'conv_1__220',
#   733: 'conv_1__221',
#   734: 'conv_1__222',
#   735: 'conv_1__223',
#   736: 'conv_1__224',
#   737: 'conv_1__225',
#   738: 'conv_1__226',
#   739: 'conv_1__227',
#   740: 'conv_1__228',
#   741: 'conv_1__229',
#   742: 'conv_1__230',
#   743: 'conv_1__231',
#   744: 'conv_1__232',
#   745: 'conv_1__233',
#   746: 'conv_1__234',
#   747: 'conv_1__235',
#   748: 'conv_1__236',
#   749: 'conv_1__237',
#   750: 'conv_1__238',
#   751: 'conv_1__239',
#   752: 'conv_1__240',
#   753: 'conv_1__241',
#   754: 'conv_1__242',
#   755: 'conv_1__243',
#   756: 'conv_1__244',
#   757: 'conv_1__245',
#   758: 'conv_1__246',
#   759: 'conv_1__247',
#   760: 'conv_1__248',
#   761: 'conv_1__249',
#   762: 'conv_1__250',
#   763: 'conv_1__251',
#   764: 'conv_1__252',
#   765: 'conv_1__253',
#   766: 'conv_1__254',
#   767: 'conv_1__255',
#   768: 'conv_1__256',
#   769: 'conv_1__257',
#   770: 'conv_1__258',
#   771: 'conv_1__259',
#   772: 'conv_1__260',
#   773: 'conv_1__261',
#   774: 'conv_1__262',
#   775: 'conv_1__263',
#   776: 'conv_1__264',
#   777: 'conv_1__265',
#   778: 'conv_1__266',
#   779: 'conv_1__267',
#   780: 'conv_1__268',
#   781: 'conv_1__269',
#   782: 'conv_1__270',
#   783: 'conv_1__271',
#   784: 'conv_1__272',
#   785: 'conv_1__273',
#   786: 'conv_1__274',
#   787: 'conv_1__275',
#   788: 'conv_1__276',
#   789: 'conv_1__277',
#   790: 'conv_1__278',
#   791: 'conv_1__279',
#   792: 'conv_1__280',
#   793: 'conv_1__281',
#   794: 'conv_1__282',
#   795: 'conv_1__283',
#   796: 'conv_1__284',
#   797: 'conv_1__285',
#   798: 'conv_1__286',
#   799: 'conv_1__287',
#   800: 'conv_1__288',
#   801: 'conv_1__289',
#   802: 'conv_1__290',
#   803: 'conv_1__291',
#   804: 'conv_1__292',
#   805: 'conv_1__293',
#   806: 'conv_1__294',
#   807: 'conv_1__295',
#   808: 'conv_1__296',
#   809: 'conv_1__297',
#   810: 'conv_1__298',
#   811: 'conv_1__299',
#   812: 'conv_1__300',
#   813: 'conv_1__301',
#   814: 'conv_1__302',
#   815: 'conv_1__303',
#   816: 'conv_1__304',
#   817: 'conv_1__305',
#   818: 'conv_1__306',
#   819: 'conv_1__307',
#   820: 'conv_1__308',
#   821: 'conv_1__309',
#   822: 'conv_1__310',
#   823: 'conv_1__311',
#   824: 'conv_1__312',
#   825: 'conv_1__313',
#   826: 'conv_1__314',
#   827: 'conv_1__315',
#   828: 'conv_1__316',
#   829: 'conv_1__317',
#   830: 'conv_1__318',
#   831: 'conv_1__319',
#   832: 'conv_1__320',
#   833: 'conv_1__321',
#   834: 'conv_1__322',
#   835: 'conv_1__323',
#   836: 'conv_1__324',
#   837: 'conv_1__325',
#   838: 'conv_1__326',
#   839: 'conv_1__327',
#   840: 'conv_1__328',
#   841: 'conv_1__329',
#   842: 'conv_1__330',
#   843: 'conv_1__331',
#   844: 'conv_1__332',
#   845: 'conv_1__333',
#   846: 'conv_1__334',
#   847: 'conv_1__335',
#   848: 'conv_1__336',
#   849: 'conv_1__337',
#   850: 'conv_1__338',
#   851: 'conv_1__339',
#   852: 'conv_1__340',
#   853: 'conv_1__341',
#   854: 'conv_1__342',
#   855: 'conv_1__343',
#   856: 'conv_1__344',
#   857: 'conv_1__345',
#   858: 'conv_1__346',
#   859: 'conv_1__347',
#   860: 'conv_1__348',
#   861: 'conv_1__349',
#   862: 'conv_1__350',
#   863: 'conv_1__351',
#   864: 'conv_1__352',
#   865: 'conv_1__353',
#   866: 'conv_1__354',
#   867: 'conv_1__355',
#   868: 'conv_1__356',
#   869: 'conv_1__357',
#   870: 'conv_1__358',
#   871: 'conv_1__359',
#   872: 'conv_1__360',
#   873: 'conv_1__361',
#   874: 'conv_1__362',
#   875: 'conv_1__363',
#   876: 'conv_1__364',
#   877: 'conv_1__365',
#   878: 'conv_1__366',
#   879: 'conv_1__367',
#   880: 'conv_1__368',
#   881: 'conv_1__369',
#   882: 'conv_1__370',
#   883: 'conv_1__371',
#   884: 'conv_1__372',
#   885: 'conv_1__373',
#   886: 'conv_1__374',
#   887: 'conv_1__375',
#   888: 'conv_1__376',
#   889: 'conv_1__377',
#   890: 'conv_1__378',
#   891: 'conv_1__379',
#   892: 'conv_1__380',
#   893: 'conv_1__381',
#   894: 'conv_1__382',
#   895: 'conv_1__383',
#   896: 'conv_1__384',
#   897: 'conv_1__385',
#   898: 'conv_1__386',
#   899: 'conv_1__387',
#   900: 'conv_1__388',
#   901: 'conv_1__389',
#   902: 'conv_1__390',
#   903: 'conv_1__391',
#   904: 'conv_1__392',
#   905: 'conv_1__393',
#   906: 'conv_1__394',
#   907: 'conv_1__395',
#   908: 'conv_1__396',
#   909: 'conv_1__397',
#   910: 'conv_1__398',
#   911: 'conv_1__399',
#   912: 'conv_1__400',
#   913: 'conv_1__401',
#   914: 'conv_1__402',
#   915: 'conv_1__403',
#   916: 'conv_1__404',
#   917: 'conv_1__405',
#   918: 'conv_1__406',
#   919: 'conv_1__407',
#   920: 'conv_1__408',
#   921: 'conv_1__409',
#   922: 'conv_1__410',
#   923: 'conv_1__411',
#   924: 'conv_1__412',
#   925: 'conv_1__413',
#   926: 'conv_1__414',
#   927: 'conv_1__415',
#   928: 'conv_1__416',
#   929: 'conv_1__417',
#   930: 'conv_1__418',
#   931: 'conv_1__419',
#   932: 'conv_1__420',
#   933: 'conv_1__421',
#   934: 'conv_1__422',
#   935: 'conv_1__423',
#   936: 'conv_1__424',
#   937: 'conv_1__425',
#   938: 'conv_1__426',
#   939: 'conv_1__427',
#   940: 'conv_1__428',
#   941: 'conv_1__429',
#   942: 'conv_1__430',
#   943: 'conv_1__431',
#   944: 'conv_1__432',
#   945: 'conv_1__433',
#   946: 'conv_1__434',
#   947: 'conv_1__435',
#   948: 'conv_1__436',
#   949: 'conv_1__437',
#   950: 'conv_1__438',
#   951: 'conv_1__439',
#   952: 'conv_1__440',
#   953: 'conv_1__441',
#   954: 'conv_1__442',
#   955: 'conv_1__443',
#   956: 'conv_1__444',
#   957: 'conv_1__445',
#   958: 'conv_1__446',
#   959: 'conv_1__447',
#   960: 'conv_1__448',
#   961: 'conv_1__449',
#   962: 'conv_1__450',
#   963: 'conv_1__451',
#   964: 'conv_1__452',
#   965: 'conv_1__453',
#   966: 'conv_1__454',
#   967: 'conv_1__455',
#   968: 'conv_1__456',
#   969: 'conv_1__457',
#   970: 'conv_1__458',
#   971: 'conv_1__459',
#   972: 'conv_1__460',
#   973: 'conv_1__461',
#   974: 'conv_1__462',
#   975: 'conv_1__463',
#   976: 'conv_1__464',
#   977: 'conv_1__465',
#   978: 'conv_1__466',
#   979: 'conv_1__467',
#   980: 'conv_1__468',
#   981: 'conv_1__469',
#   982: 'conv_1__470',
#   983: 'conv_1__471',
#   984: 'conv_1__472',
#   985: 'conv_1__473',
#   986: 'conv_1__474',
#   987: 'conv_1__475',
#   988: 'conv_1__476',
#   989: 'conv_1__477',
#   990: 'conv_1__478',
#   991: 'conv_1__479',
#   992: 'conv_1__480',
#   993: 'conv_1__481',
#   994: 'conv_1__482',
#   995: 'conv_1__483',
#   996: 'conv_1__484',
#   997: 'conv_1__485',
#   998: 'conv_1__486',
#   999: 'conv_1__487',
#   ...})

# %%
all_phonesymbols
# Out:
# [array(['DH', 'AH0', ' ', 'F', 'AO1', 'R', 'M', 'Z', ' ', 'AH1', 'V', ' ',
#         'P', 'R', 'IH1', 'N', 'T', 'AH0', 'D', ' ', 'L', 'EH1', 'T', 'ER0',
#         'Z', ' ', 'SH', 'UH1', 'D', ' ', 'B', 'IY1', ' ', 'B', 'Y', 'UW1',
#         'T', 'AH0', 'F', 'AH0', 'L', ',', ' ', 'AH0', 'N', 'D', ' ', 'DH',
#         'AE1', 'T', ' ', 'DH', 'EH1', 'R', ' ', 'ER0', 'EY1', 'N', 'JH',
#         'M', 'AH0', 'N', 'T', ' ', 'AA1', 'N', ' ', 'DH', 'AH0', ' ', 'P',
#         'EY1', 'JH', ' ', 'SH', 'UH1', 'D', ' ', 'B', 'IY1', ' ', 'R',
#         'IY1', 'Z', 'AH0', 'N', 'AH0', 'B', 'AH0', 'L', ' ', 'AH0', 'N',
#         'D', ' ', 'EY1', ' ', 'HH', 'EH1', 'L', 'P', ' ', 'T', 'UW1', ' ',
#         'DH', 'AH0', ' ', 'SH', 'EY1', 'P', 'AH0', 'L', 'IH2', 'N', 'Z',
#         ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'L', 'EH1', 'T', 'ER0',
#         'Z', ' ', 'DH', 'EH0', 'M', 'S', 'EH1', 'L', 'V', 'Z', '.'],
#        dtype='<U3'),
#  array(['IH1', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'S', 'EH1', 'D', ' ', 'IH0',
#         'N', ' ', 'L', 'AE1', 'S', 'T', ' ', 'Y', 'IH1', 'R', 'Z', ' ',
#         'D', 'EH2', 'M', 'AH0', 'K', 'R', 'AE1', 'T', 'IH0', 'K', ' ', 'P',
#         'L', 'AE1', 'T', 'F', 'AO2', 'R', 'M', ','], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'AY1', 'W', 'IH2', 'T', 'N', 'AH0', 'S', 'IH0',
#         'Z', ' ', 'V', 'EH1', 'R', 'IY0', ' ', 'IH0', 'N', ' ', 'DH',
#         'EH1', 'R', ' ', 'AY0', 'D', 'EH2', 'N', 'T', 'AH0', 'F', 'AH0',
#         'K', 'EY1', 'SH', 'AH0', 'N', ' ', 'AH1', 'V', ' ', 'DH', 'AH0',
#         ' ', 'JH', 'AE1', 'K', 'AH0', 'T', '.'], dtype='<U3'),
#  array(['M', 'IH1', 'S', 'IH0', 'Z', '.', ' ', 'ER1', 'L', 'IY0', 'N', ' ',
#         'R', 'AA1', 'B', 'ER0', 'T', 'S', ',', ' ', 'DH', 'AH0', ' ', 'HH',
#         'AW1', 'S', 'K', 'IY2', 'P', 'ER0', ' ', 'AE1', 'T', ' ', 'AO1',
#         'Z', 'W', 'AO0', 'L', 'D', 'Z', ' ', 'R', 'UW1', 'M', 'IH0', 'NG',
#         'G', 'HH', 'AW2', 'S', ' ', 'AH0', 'N', 'D', ' ', 'DH', 'AH0', ' ',
#         'L', 'AE1', 'S', 'T', ' ', 'P', 'ER1', 'S', 'AH0', 'N', ' ', 'N',
#         'OW1', 'N', ' ', 'T', 'UW1', ' ', 'HH', 'AE1', 'V', ' ', 'S',
#         'IY1', 'N', ' ', 'HH', 'IH1', 'M', ' ', 'B', 'IH0', 'F', 'AO1',
#         'R', ' ', 'HH', 'IY1', ' ', 'R', 'IY1', 'CH', 'T', ' ', 'T', 'EH1',
#         'N', 'TH', ' ', 'S', 'T', 'R', 'IY1', 'T', ' ', 'AH0', 'N', 'D',
#         ' ', 'P', 'AE1', 'T', 'AH0', 'N', ' ', 'AE1', 'V', 'AH0', 'N',
#         'UW2', ','], dtype='<U3'),
#  array(['T', 'EH1', 'D', ' ', 'K', 'AE1', 'L', 'AH0', 'W', 'EY0', ',', ' ',
#         'HH', 'UW1', ' ', 'S', 'AO1', ' ', 'DH', 'AH0', ' ', 'G', 'AH1',
#         'N', 'M', 'AH0', 'N', ' ', 'M', 'OW1', 'M', 'AH0', 'N', 'T', 'S',
#         ' ', 'AE1', 'F', 'T', 'ER0', ' ', 'DH', 'AH0', ' ', 'SH', 'UW1',
#         'T', 'IH0', 'NG', ',', ' ', 'T', 'EH1', 'S', 'T', 'IH0', 'F',
#         'AY2', 'D', ' ', 'DH', 'AE1', 'T', ' ', 'K', 'AH0', 'M', 'IH1',
#         'SH', 'AH0', 'N', ' ', 'IH0', 'G', 'Z', 'IH1', 'B', 'IH0', 'T',
#         ' ', 'N', 'AH1', 'M', 'B', 'ER0', ' ', 'W', 'AH1', 'N', ' ', 'S',
#         'IH0', 'K', 'S', 'T', 'IH1', 'T', 'W', 'AA2'], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'P', 'EY1', 'IH0', 'NG', ' ', 'G', 'R',
#         'EY1', 'T', ' ', 'AH0', 'T', 'EH1', 'N', 'SH', 'AH0', 'N', ' ',
#         'T', 'UW1', ' ', 'DH', 'AH0', ' ', 'P', 'R', 'EH1', 'S', ' ', 'W',
#         'ER1', 'K', ' ', 'AO1', 'R', ' ', 'AE1', 'K', 'CH', 'AH0', 'W',
#         'AH0', 'L', ' ', 'P', 'R', 'AA1', 'S', 'EH2', 'S', ' ', 'AH1', 'V',
#         ' ', 'P', 'R', 'IH1', 'N', 'T', 'IH0', 'NG', ','], dtype='<U3'),
#  array(['K', 'AA1', 'N', 'S', 'AH0', 'K', 'W', 'AH0', 'N', 'T', 'L', 'IY0',
#         ',', ' ', 'AO2', 'L', 'DH', 'OW1', ' ', 'DH', 'EH1', 'R', ' ', 'N',
#         'EH1', 'V', 'ER0', ' ', 'K', 'AE1', 'N', ' ', 'B', 'IY1', ' ', 'M',
#         'AO1', 'R', ' ', 'DH', 'AE1', 'N', ' ', 'F', 'IH0', 'F', 'T',
#         'IY1', 'N', ',', ' ', 'DH', 'EH1', 'R', ' ', 'M', 'EY1', ' ', 'B',
#         'IY1', ' ', 'OW1', 'N', 'L', 'IY0', ' ', 'F', 'AO1', 'R', 'T',
#         'IY1', 'N', ',', ' ', 'AO1', 'R', ' ', 'TH', 'ER1', 'T', 'IY1',
#         'N', ',', ' ', 'AO1', 'R', ' ', 'T', 'W', 'EH1', 'L', 'V', '.'],
#        dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'DH', 'EH1', 'R', ' ', 'M', 'EY1', ' ', 'B',
#         'IY1', ' ', 'OW1', 'N', 'L', 'IY0', ' ', 'N', 'AY1', 'N', '.'],
#        dtype='<U3'),
#  array(['W', 'IH1', 'CH', ' ', 'W', 'AA1', 'Z', ' ', 'JH', 'EH1', 'N',
#         'ER0', 'AH0', 'L', 'IY0', ' ', 'M', 'AO1', 'R', ' ', 'F', 'AO1',
#         'R', 'M', 'AH0', 'L', 'IY0', ' ', 'G', 'AA1', 'TH', 'IH0', 'K',
#         ' ', 'DH', 'AE1', 'N', ' ', 'DH', 'AH0', ' ', 'P', 'R', 'IH1', 'N',
#         'T', 'IH0', 'NG', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'JH',
#         'ER1', 'M', 'AH0', 'N', ' ', 'W', 'ER1', 'K', 'M', 'IH0', 'N', ','],
#        dtype='<U3'),
#  array(['W', 'AH1', 'T', ' ', 'D', 'UW1', ' ', 'DH', 'EY1', ' ', 'M',
#         'IY1', 'N', ' ', 'B', 'AY1', ' ', 'DH', 'AH0', ' ', 'W', 'ER1',
#         'D', 'Z', ' ', 'P', 'AE1', 'K', 'IH0', 'NG', ' ', 'DH', 'AH0', ' ',
#         'K', 'AO1', 'R', 'T', '?'], dtype='<U3'),
#  array(['AE1', 'F', 'T', 'ER0', ' ', 'DH', 'AH0', ' ', 'EH1', 'N', 'D',
#         ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'F', 'IH0', 'F', 'T',
#         'IY1', 'N', 'TH', ' ', 'S', 'EH1', 'N', 'CH', 'ER0', 'IY0', ' ',
#         'DH', 'AH0', ' ', 'D', 'EH2', 'G', 'R', 'AH0', 'D', 'EY1', 'SH',
#         'AH0', 'N', ' ', 'AH1', 'V', ' ', 'P', 'R', 'IH1', 'N', 'T', 'IH0',
#         'NG', ',', ' ', 'AH0', 'S', 'P', 'EH1', 'SH', 'L', 'IY0', ' ',
#         'IH0', 'N', ' ', 'JH', 'ER1', 'M', 'AH0', 'N', 'IY0', ' ', 'AH0',
#         'N', 'D', ' ', 'IH1', 'T', 'AH0', 'L', 'IY0', ','], dtype='<U3'),
#  array(['K', 'AE1', 'S', 'L', 'AH0', 'N', ' ', 'T', 'AY1', 'P', ' ', 'IH1',
#         'Z', ' ', 'K', 'L', 'IH1', 'R', ' ', 'AH0', 'N', 'D', ' ', 'N',
#         'IY1', 'T', ',', ' ', 'AH0', 'N', 'D', ' ', 'F', 'EH1', 'R', 'L',
#         'IY0', ' ', 'W', 'EH1', 'L', ' ', 'D', 'IH0', 'Z', 'AY1', 'N', 'D',
#         ';'], dtype='<U3'),
#  array(['D', 'IH0', 'M', 'AA1', 'K', 'R', 'AH0', 'S', 'IY0', ' ', 'W',
#         'IH1', 'L', ' ', 'HH', 'AE1', 'V', ' ', 'F', 'EY1', 'L', 'D', ' ',
#         'F', 'AA1', 'R', ' ', 'B', 'IH0', 'AA1', 'N', 'D', ' ', 'DH',
#         'AH0', ' ', 'IH2', 'M', 'P', 'AO1', 'R', 'T', 'AH0', 'N', 'S', ' ',
#         'T', 'UW1', ' ', 'IH1', 'T', ' ', 'AH1', 'V', ' ', 'EH1', 'N',
#         'IY0', ' ', 'K', 'IH1', 'NG', ' ', 'AH1', 'V', ' ', 'P', 'R',
#         'EH1', 'S', 'IH0', 'D', 'AH0', 'N', 'T', ' ', 'K', 'AH0', 'N', 'S',
#         'ER1', 'N', 'IH0', 'NG', ' ', 'DH', 'AH0', ' ', 'JH', 'UW0', 'D',
#         'IH1', 'SH', 'IY0', 'EH2', 'R', 'IY0', '.'], dtype='<U3'),
#  array(['AO1', 'Z', 'W', 'AO0', 'L', 'D', ' ', 'R', 'OW1', 'Z', ' ', 'F',
#         'R', 'AH1', 'M', ' ', 'HH', 'IH1', 'Z', ' ', 'S', 'IY1', 'T', ',',
#         ' ', 'B', 'R', 'IH1', 'NG', 'IH0', 'NG', ' ', 'AH1', 'P', ' ', 'B',
#         'OW1', 'TH', ' ', 'HH', 'AE1', 'N', 'D', 'Z', '.'], dtype='<U3'),
#  array(['W', 'ER1', ' ', 'IH2', 'N', 'D', 'UW1', 'S', 'T', ' ', 'T', 'UW1',
#         ' ', 'K', 'AH1', 'T', ' ', 'P', 'AH1', 'N', 'CH', 'IH0', 'Z', ' ',
#         'F', 'AO1', 'R', ' ', 'EY1', ' ', 'S', 'IH1', 'R', 'IY0', 'Z', ' ',
#         'AH1', 'V', ' ', 'OW1', 'L', 'D', ' ', 'S', 'T', 'AY1', 'L', ' ',
#         'L', 'EH1', 'T', 'ER0', 'Z', '.'], dtype='<U3'),
#  array(['HH', 'AE1', 'V', ' ', 'N', 'AW1', ' ', 'K', 'AH1', 'M', ' ',
#         'IH0', 'N', 'T', 'UW1', ' ', 'JH', 'EH1', 'N', 'ER0', 'AH0', 'L',
#         ' ', 'Y', 'UW1', 'S', ' ', 'AH0', 'N', 'D', ' ', 'AA1', 'R', ' ',
#         'AA1', 'B', 'V', 'IY0', 'AH0', 'S', 'L', 'IY0', ' ', 'EY1', ' ',
#         'G', 'R', 'EY1', 'T', ' ', 'IH2', 'M', 'P', 'R', 'UW1', 'V', 'M',
#         'AH0', 'N', 'T', ' ', 'AA1', 'N', ' ', 'DH', 'AH0', ' ', 'AO1',
#         'R', 'D', 'AH0', 'N', 'EH2', 'R', 'IY0', ' ', 'M', 'AA1', 'D',
#         'ER0', 'N', ' ', 'S', 'T', 'AY1', 'L', ' ', 'IH0', 'N', ' ', 'Y',
#         'UW1', 'S', ' ', 'IH0', 'N', ' ', 'IH1', 'NG', 'G', 'L', 'AH0',
#         'N', 'D', ',', ' ', 'W', 'IH1', 'CH', ' ', 'IH1', 'Z', ' ', 'IH0',
#         'N', ' ', 'F', 'AE1', 'K', 'T', ' ', 'DH', 'AH0', ' ', 'B', 'OW0',
#         'D', 'OW1', 'N', 'IY0', ' ', 'T', 'AY1', 'P'], dtype='<U3'),
#  array(['HH', 'IY1', 'R', ' ', 'AH0', 'N', 'D', ' ', 'DH', 'EH1', 'R', ' ',
#         'EY1', ' ', 'B', 'UH1', 'K', ' ', 'IH1', 'Z', ' ', 'P', 'R', 'IH1',
#         'N', 'T', 'AH0', 'D', ' ', 'IH0', 'N', ' ', 'F', 'R', 'AE1', 'N',
#         'S', ' ', 'AO1', 'R', ' ', 'JH', 'ER1', 'M', 'AH0', 'N', 'IY0',
#         ' ', 'W', 'IH1', 'DH', ' ', 'S', 'AH1', 'M', ' ', 'P', 'R', 'IY0',
#         'T', 'EH1', 'N', 'SH', 'AH0', 'N', ' ', 'T', 'UW1', ' ', 'G',
#         'UH1', 'D', ' ', 'T', 'EY1', 'S', 'T', ','], dtype='<U3'),
#  array(['S', 'AH1', 'M', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'AO1',
#         'F', 'AH0', 'S', 'ER0', 'Z', ' ', 'S', 'AO1', ' ', 'AO1', 'Z', 'W',
#         'AO0', 'L', 'D', ' ', 'S', 'T', 'R', 'AY1', 'K', ' ', 'M', 'AH0',
#         'K', 'D', 'AA1', 'N', 'AH0', 'L', 'D', ' ', 'W', 'IH1', 'DH', ' ',
#         'HH', 'IH1', 'Z', ' ', 'F', 'IH1', 'S', 'T', '.', ' ', 'M', 'OW1',
#         'S', 'T', ' ', 'AH1', 'V', ' ', 'DH', 'EH1', 'M', ' ', 'HH', 'ER1',
#         'D', ' ', 'EY1', ' ', 'K', 'L', 'IH1', 'K', ' ', 'W', 'IH1', 'CH',
#         ' ', 'DH', 'EY1', ' ', 'AH0', 'S', 'UW1', 'M', 'D', ' ', 'T',
#         'UW1', ' ', 'B', 'IY1', ' ', 'EY1', ' ', 'K', 'L', 'IH1', 'K', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'HH', 'AE1', 'M', 'ER0', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'R', 'IH0', 'V', 'AA1', 'L',
#         'V', 'ER0', '.'], dtype='<U3'),
#  array(['P', 'R', 'AA1', 'B', 'ER0', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'DH',
#         'EH1', 'N', ' ', 'AH0', 'D', 'M', 'IH1', 'T', 'AH0', 'D', ' ',
#         'AE1', 'Z', ' ', 'EY1', ' ', 'W', 'IH1', 'T', 'N', 'AH0', 'S', ',',
#         ' ', 'AH0', 'N', 'D', ' ', 'DH', 'AH0', ' ', 'K', 'EY1', 'S', ' ',
#         'W', 'AA1', 'Z', ' ', 'F', 'UH1', 'L', 'IY0', ' ', 'P', 'R', 'UW1',
#         'V', 'D', ' ', 'AH0', 'G', 'EH1', 'N', 'S', 'T', ' ', 'TH', 'ER1',
#         'T', 'AH0', 'L', ',', ' ', 'HH', 'UW1', ' ', 'W', 'AA1', 'Z', ' ',
#         'HH', 'AE1', 'NG', 'D', ' ', 'IH0', 'N', ' ', 'F', 'R', 'AH1', 'N',
#         'T', ' ', 'AH1', 'V', ' ', 'HH', 'ER1', 'T', 'F', 'ER0', 'D', ' ',
#         'JH', 'EY1', 'L', '.'], dtype='<U3'),
#  array(['HH', 'AH1', 'N', 'T', ',', ' ', 'IH0', 'N', ' ', 'K', 'AH0', 'N',
#         'S', 'IH2', 'D', 'ER0', 'EY1', 'SH', 'AH0', 'N', ' ', 'AH1', 'V',
#         ' ', 'DH', 'AH0', ' ', 'IH2', 'N', 'F', 'AO2', 'R', 'M', 'EY1',
#         'SH', 'AH0', 'N', ' ', 'HH', 'IY1', ' ', 'HH', 'AE1', 'D', ' ',
#         'G', 'IH1', 'V', 'AH0', 'N', ',', ' ', 'IH0', 'S', 'K', 'EY1', 'P',
#         'T', ' ', 'D', 'EH1', 'TH', ',', ' ', 'AH0', 'N', 'D', ' ', 'W',
#         'AA1', 'Z', ' ', 'S', 'EH1', 'N', 'T', 'AH0', 'N', 'S', 'T', ' ',
#         'T', 'UW1', ' ', 'T', 'R', 'AE2', 'N', 'S', 'P', 'ER0', 'T', 'EY1',
#         'SH', 'AH0', 'N', ' ', 'F', 'AO1', 'R', ' ', 'L', 'AY1', 'F', '.'],
#        dtype='<U3'),
#  array(['B', 'AH1', 'T', ' ', 'B', 'ER1', 'K', ' ', 'AH0', 'N', 'D', ' ',
#         'HH', 'EH1', 'R', ' ', 'HH', 'AE1', 'D', ' ', 'DH', 'EH1', 'R',
#         ' ', 'IH1', 'M', 'IH0', 'T', 'EY2', 'T', 'ER0', 'Z', ' ', 'F',
#         'ER1', 'DH', 'ER0', ' ', 'S', 'AW1', 'TH', ','], dtype='<U3'),
#  array(['W', 'UH1', 'D', ' ', 'B', 'IY1', ' ', 'DH', 'AH0', ' ', 'F',
#         'ER1', 'S', 'T', ' ', 'T', 'UW1', ' ', 'IH0', 'K', 'S', 'K', 'L',
#         'EY1', 'M', ' ', 'AE1', 'Z', ' ', 'S', 'UW1', 'N', ' ', 'AE1', 'Z',
#         ' ', 'AE1', 'N', ' ', 'AH0', 'M', 'EH1', 'N', 'D', 'M', 'AH0', 'N',
#         'T', ' ', 'W', 'AA1', 'Z', ' ', 'P', 'R', 'AH0', 'P', 'OW1', 'Z',
#         'D'], dtype='<U3'),
#  array(['OW1', 'N', 'L', 'IY0', ' ', 'N', 'AA1', 'M', 'AH0', 'N', 'AH0',
#         'L', 'IY0', ' ', 'S', 'OW1', ',', ' ', 'HH', 'AW2', 'EH1', 'V',
#         'ER0', ',', ' ', 'IH0', 'N', ' ', 'M', 'EH1', 'N', 'IY0', ' ', 'K',
#         'EY1', 'S', 'AH0', 'Z', ',', ' ', 'S', 'IH1', 'N', 'S', ' ', 'W',
#         'EH1', 'N', ' ', 'HH', 'IY1', ' ', 'Y', 'UW1', 'S', 'IH0', 'Z',
#         ' ', 'EY1', ' ', 'HH', 'EH1', 'D', 'L', 'AY2', 'N', ' ', 'HH',
#         'IY1', ' ', 'K', 'AW1', 'N', 'T', 'S', ' ', 'DH', 'AE1', 'T', ' ',
#         'IH0', 'N', ','], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'IH0', 'N', ' ', 'W', 'AH1', 'N', ' ', 'K',
#         'AO1', 'R', 'N', 'ER0', ',', ' ', 'AE1', 'T', ' ', 'S', 'AH1', 'M',
#         ' ', 'D', 'EH1', 'P', 'TH', ',', ' ', 'EY1', ' ', 'B', 'AH1', 'N',
#         'D', 'AH0', 'L', ' ', 'AH1', 'V', ' ', 'K', 'L', 'OW1', 'DH', 'Z',
#         ' ', 'W', 'ER1', ' ', 'AH0', 'N', 'ER1', 'TH', 'T', ',', ' ', 'W',
#         'IH1', 'CH', ',', ' ', 'W', 'IH1', 'DH', ' ', 'EY1', ' ', 'HH',
#         'EH1', 'R', 'IY0', ' ', 'K', 'AE1', 'P', ','], dtype='<U3'),
#  array(['SH', 'AO1', 'R', 'T', 'L', 'IY0', ' ', 'B', 'IH0', 'F', 'AO1',
#         'R', ' ', 'DH', 'AH0', ' ', 'D', 'EY1', ' ', 'F', 'IH1', 'K', 'S',
#         'T', ' ', 'F', 'AO1', 'R', ' ', 'EH2', 'K', 'S', 'AH0', 'K', 'Y',
#         'UW1', 'SH', 'AH0', 'N', ',', ' ', 'B', 'IH1', 'SH', 'AH0', 'P',
#         ' ', 'M', 'EY1', 'D', ' ', 'EY1', ' ', 'F', 'UH1', 'L', ' ', 'K',
#         'AH0', 'N', 'F', 'EH1', 'SH', 'AH0', 'N', ',', ' ', 'DH', 'AH0',
#         ' ', 'B', 'AH1', 'L', 'K', ' ', 'AH1', 'V', ' ', 'W', 'IH1', 'CH',
#         ' ', 'B', 'AO1', 'R', ' ', 'DH', 'AH0', ' ', 'IH1', 'M', 'P', 'R',
#         'EH0', 'S', ' ', 'AH1', 'V', ' ', 'T', 'R', 'UW1', 'TH', ','],
#        dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'IH0', 'S', 'EH1', 'N', 'SH', 'AH0', 'L', ' ',
#         'P', 'OY1', 'N', 'T', ' ', 'T', 'UW1', ' ', 'B', 'IY1', ' ', 'R',
#         'IH0', 'M', 'EH1', 'M', 'B', 'ER0', 'D', ' ', 'IH1', 'Z', ' ',
#         'DH', 'AE1', 'T', ' ', 'DH', 'AH0', ' ', 'AO1', 'R', 'N', 'AH0',
#         'M', 'AH0', 'N', 'T', ',', ' ', 'W', 'AH2', 'T', 'EH1', 'V', 'ER0',
#         ' ', 'IH1', 'T', ' ', 'IH1', 'Z', ',', ' ', 'W', 'EH1', 'DH',
#         'ER0', ' ', 'P', 'IH1', 'K', 'CH', 'ER0', ' ', 'AO1', 'R', ' ',
#         'P', 'AE1', 'T', 'ER0', 'N', 'UH2', 'K', 'ER0', ',', ' ', 'SH',
#         'UH1', 'D', ' ', 'F', 'AO1', 'R', 'M', ' ', 'P', 'AA1', 'R', 'T',
#         ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'P', 'EY1', 'JH', ','],
#        dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'P', 'AH0', 'Z', 'IH1', 'SH', 'AH0', 'N', ' ',
#         'AH1', 'V', ' ', 'AW1', 'ER0', ' ', 'S', 'OW0', 'S', 'AY1', 'IH0',
#         'T', 'IY0', ' ', 'DH', 'AE1', 'T', ' ', 'EY1', ' ', 'W', 'ER1',
#         'K', ' ', 'AH1', 'V', ' ', 'Y', 'UW0', 'T', 'IH1', 'L', 'AH0', 'T',
#         'IY0', ' ', 'M', 'AY1', 'T', ' ', 'B', 'IY1', ' ', 'AO1', 'L', 'S',
#         'OW0', ' ', 'EY1', ' ', 'W', 'ER1', 'K', ' ', 'AH1', 'V', ' ',
#         'AA1', 'R', 'T', ',', ' ', 'IH1', 'F', ' ', 'W', 'IY1', ' ', 'K',
#         'EH1', 'R', 'D', ' ', 'T', 'UW1', ' ', 'M', 'EY1', 'K', ' ', 'IH1',
#         'T', ' ', 'S', 'OW1', '.'], dtype='<U3'),
#  array(['B', 'AH1', 'T', ' ', 'DH', 'AH0', ' ', 'AH0', 'F', 'EH1', 'R',
#         ' ', 'S', 'T', 'IH1', 'L', ' ', 'R', 'IH0', 'M', 'EY1', 'N', 'D',
#         ' ', 'EY1', ' ', 'P', 'R', 'OW0', 'F', 'AW1', 'N', 'D', ' ', 'M',
#         'IH1', 'S', 'T', 'ER0', 'IY0', '.', ' ', 'N', 'OW1', ' ', 'L',
#         'AY1', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'TH', 'R', 'OW1', 'N', ' ',
#         'AH0', 'P', 'AA1', 'N', ' ', 'IH1', 'T', ' ', 'T', 'IH1', 'L', ',',
#         ' ', 'T', 'AH0', 'W', 'AO1', 'R', 'D', 'Z', ' ', 'DH', 'AH0', ' ',
#         'EH1', 'N', 'D', ' ', 'AH1', 'V', ' ', 'M', 'AA1', 'R', 'CH', ','],
#        dtype='<U3'),
#  array(['W', 'EH1', 'DH', 'ER0', ' ', 'IH1', 'T', ' ', 'W', 'AA1', 'Z',
#         ' ', 'G', 'R', 'IY1', 'D', ' ', 'AO1', 'R', ' ', 'EY1', ' ', 'K',
#         'W', 'AO1', 'R', 'AH0', 'L', ' ', 'DH', 'AE1', 'T', ' ', 'D', 'R',
#         'OW1', 'V', ' ', 'G', 'R', 'IY1', 'N', 'AH0', 'K', 'ER0', ' ', 'T',
#         'UW1', ' ', 'DH', 'AH0', ' ', 'D', 'EH1', 'S', 'P', 'R', 'IH0',
#         'T', ' ', 'D', 'IY1', 'D', ' ', 'R', 'IH0', 'M', 'EY1', 'N', 'Z',
#         ' ', 'AH0', 'B', 'S', 'K', 'Y', 'UH1', 'R', '.'], dtype='<U3'),
#  array(['W', 'AH1', 'N', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'ER1',
#         'L', 'IY0', 'AH0', 'S', 'T', ' ', 'AH1', 'V', ' ', 'DH', 'AH0',
#         ' ', 'B', 'IH1', 'G', ' ', 'AA1', 'P', 'ER0', 'EY2', 'T', 'ER0',
#         'Z', ' ', 'IH0', 'N', ' ', 'F', 'R', 'AO1', 'JH', 'AH0', 'L',
#         'AH0', 'N', 'T', ' ', 'F', 'AH0', 'N', 'AE1', 'N', 'S', ' ', 'W',
#         'AA1', 'Z', ' ', 'EH1', 'D', 'W', 'ER0', 'D', ' ', 'B', 'OW1', 'M',
#         'AO0', 'N', 'T', ' ', 'S', 'M', 'IH1', 'TH', ','], dtype='<U3'),
#  array(['HH', 'AE1', 'Z', ' ', 'N', 'OW1', ' ', 'P', 'ER1', 'M', 'AA0',
#         'N', 'EH2', 'N', 'T', ' ', 'D', 'AY0', 'JH', 'EH1', 'S', 'T',
#         'IH0', 'V', ' ', 'K', 'AE1', 'V', 'AH0', 'T', 'IY0', ' ', 'AO1',
#         'R', ' ', 'M', 'AW1', 'DH', ',', ' ', 'B', 'AH1', 'T', ' ', 'T',
#         'EY1', 'K', 'S', ' ', 'IH0', 'N', ' ', 'IH1', 'T', 'S', ' ', 'F',
#         'UW1', 'D', ' ', 'EH1', 'N', 'IY0', 'W', 'EH2', 'R', ' ', 'AH0',
#         'N', 'D', ' ', 'D', 'AY1', 'JH', 'EH0', 'S', 'T', 'S', ',', ' ',
#         'S', 'OW1', ' ', 'T', 'UW1', ' ', 'S', 'P', 'IY1', 'K', ',', ' ',
#         'AO1', 'L', ' ', 'OW1', 'V', 'ER0', ' ', 'IH1', 'T', 'S', ' ', 'B',
#         'AA1', 'D', 'IY0', '.'], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'IH1', 'T', ' ', 'IH1', 'Z', ' ', 'P', 'R',
#         'AA1', 'B', 'AH0', 'B', 'AH0', 'L', ' ', 'DH', 'AE1', 'T', ' ',
#         'AE1', 'M', 'IH0', 'L', 'OY2', 'D', ' ', 'S', 'AH1', 'B', 'S', 'T',
#         'AH0', 'N', 'S', 'AH0', 'Z', ' ', 'AA1', 'R', ' ', 'Y', 'UW2', 'N',
#         'AH0', 'V', 'ER1', 'S', 'AH0', 'L', 'IY0', ' ', 'P', 'R', 'EH1',
#         'Z', 'AH0', 'N', 'T', ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ',
#         'AE1', 'N', 'AH0', 'M', 'AH0', 'L', ' ', 'AO1', 'R', 'G', 'AH0',
#         'N', 'IH2', 'Z', 'AH0', 'M', ',', ' ', 'DH', 'OW1', ' ', 'N',
#         'AA1', 'T', ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ', 'P', 'R',
#         'IH0', 'S', 'AY1', 'S', ' ', 'F', 'AO1', 'R', 'M', ' ', 'AH1', 'V',
#         ' ', 'S', 'T', 'AA1', 'R', 'CH', '.'], dtype='<U3'),
#  array(['W', 'AO1', 'L', 'AH0', 'S', ' ', 'R', 'IY0', 'L', 'EY1', 'SH',
#         'AH0', 'N', 'Z', ' ', 'W', 'AO1', 'R', 'N', 'D', ' ', 'HH', 'IH1',
#         'M', ' ', 'AH0', 'G', 'EH1', 'N', 'S', 'T', ' ', 'HH', 'IH1', 'Z',
#         ' ', 'L', 'IH1', 'V', 'ER0', 'P', 'UW2', 'L', ' ', 'F', 'R', 'EH1',
#         'N', 'D', ','], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'EY1', 'T', ' ', 'K', 'AO1', 'R', 'T', 'S', ' ',
#         'AH0', 'B', 'AH1', 'V', ' ', 'IH0', 'N', 'UW1', 'M', 'ER0', 'EY2',
#         'T', 'IH0', 'D', ' ', 'W', 'ER1', ' ', 'W', 'EH1', 'L', ' ', 'S',
#         'AH0', 'P', 'L', 'AY1', 'D', ' ', 'W', 'IH1', 'DH', ' ', 'W',
#         'AO1', 'T', 'ER0', ';'], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'DH', 'AE1', 'T', ',', ' ', 'HH', 'AW2',
#         'EH1', 'V', 'ER0', ' ', 'D', 'AY0', 'V', 'ER1', 'S', ' ', 'M',
#         'EY1', ' ', 'B', 'IY1', ' ', 'DH', 'AH0', ' ', 'F', 'AE1', 'B',
#         'R', 'IH0', 'K', 'S', ' ', 'AO1', 'R', ' ', 'T', 'IH1', 'S', 'Y',
#         'UW2', 'Z', ' ', 'AH1', 'V', ' ', 'W', 'IH1', 'CH', ' ', 'DH',
#         'EH1', 'R', ' ', 'B', 'AA1', 'D', 'IY0', 'Z', ' ', 'AA1', 'R', ' ',
#         'K', 'AH0', 'M', 'P', 'OW1', 'Z', 'D', ',', ' ', 'AO1', 'L', ' ',
#         'DH', 'IY1', 'Z', ' ', 'V', 'EH1', 'R', 'IY0', 'D', ' ', 'S', 'T',
#         'R', 'AH1', 'K', 'CH', 'ER0', 'Z', ' ', 'R', 'IH0', 'Z', 'AH1',
#         'L', 'T'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'JH', 'UH1', 'R', 'IY0', ' ', 'D', 'IH1', 'D',
#         ' ', 'N', 'AA1', 'T', ' ', 'B', 'IH0', 'L', 'IY1', 'V', ' ', 'HH',
#         'IH1', 'M', ',', ' ', 'AH0', 'N', 'D', ' ', 'DH', 'AH0', ' ', 'V',
#         'ER1', 'D', 'IH0', 'K', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'F', 'AO1',
#         'R', ' ', 'DH', 'AH0', ' ', 'D', 'IH0', 'F', 'EH1', 'N', 'D',
#         'AH0', 'N', 'T', 'S', '.'], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'B', 'IH0', 'AA1', 'N', 'D', ' ', 'IH1', 'T',
#         ' ', 'W', 'AA1', 'Z', ' ', 'EY1', ' ', 'R', 'UW1', 'M', ' ', 'K',
#         'AO1', 'L', 'D', ' ', 'DH', 'AH0', ' ', 'W', 'AY1', 'N', ' ', 'R',
#         'UW1', 'M', ',', ' ', 'B', 'IH0', 'K', 'AO1', 'Z', ' ', 'F', 'AO1',
#         'R', 'M', 'ER0', 'L', 'IY0', ' ', 'Y', 'UW1', 'Z', 'D', ' ', 'F',
#         'AO1', 'R', ' ', 'DH', 'AH0', ' ', 'S', 'EY1', 'L', ' ', 'AH1',
#         'V', ' ', 'W', 'AY1', 'N', ',', ' ', 'B', 'AH1', 'T'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'W', 'IH1', 'CH', ' ', 'L', 'AE1', 'T', 'ER0',
#         'L', 'IY0', ' ', 'EY1', ' ', 'K', 'AA1', 'P', 'ER0', ' ', 'HH',
#         'AE1', 'D', ' ', 'B', 'IH1', 'N', ' ', 'F', 'IH1', 'K', 'S', 'T',
#         ' ', 'F', 'AO1', 'R', ' ', 'DH', 'AH0', ' ', 'K', 'UH1', 'K',
#         'IH0', 'NG', ' ', 'AH1', 'V', ' ', 'P', 'R', 'AH0', 'V', 'IH1',
#         'ZH', 'AH0', 'N', 'Z', ' ', 'S', 'EH1', 'N', 'T', ' ', 'IH0', 'N',
#         ' ', 'B', 'AY1', ' ', 'CH', 'AE1', 'R', 'AH0', 'T', 'AH0', 'B',
#         'AH0', 'L', ' ', 'P', 'ER1', 'S', 'AH0', 'N', 'Z', '.'],
#        dtype='<U3'),
#  array(['AA1', 'N', ' ', 'IY1', 'CH', ' ', 'L', 'OW1', 'B', ' ', 'AH1',
#         'V', ' ', 'DH', 'AH0', ' ', 'B', 'AY1', 'L', 'OW2', 'D', ' ', 'L',
#         'IY1', 'F', ' ', 'AH1', 'V', ' ', 'V', 'IY1', 'N', 'AH0', 'S', ' ',
#         'F', 'L', 'AY1', 'T', 'R', 'AE2', 'P', ' ', 'AA1', 'R', ' ', 'TH',
#         'R', 'IY1', ' ', 'D', 'EH1', 'L', 'AH0', 'K', 'AH0', 'T', ' ', 'F',
#         'IH1', 'L', 'AH0', 'M', 'AH0', 'N', 'T', 'S', ' ', 'W', 'IH1',
#         'CH', ' ', 'S', 'T', 'AE1', 'N', 'D', ' ', 'AW1', 'T', ' ', 'AE1',
#         'T', ' ', 'R', 'AY1', 'T', ' ', 'AE1', 'NG', 'G', 'AH0', 'L', 'Z',
#         ' ', 'F', 'R', 'AH1', 'M', ' ', 'DH', 'AH0', ' ', 'S', 'ER1', 'F',
#         'AH0', 'S', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'L', 'IY1',
#         'F', '.'], dtype='<U3'),
#  array(['AH1', 'N', 'D', 'ER0', ' ', 'DH', 'IY1', 'Z', ' ', 'S', 'ER1',
#         'K', 'AH0', 'M', 'S', 'T', 'AE2', 'N', 'S', 'AH0', 'Z', ',', ' ',
#         'AH0', 'N', 'N', 'AE1', 'CH', 'ER0', 'AH0', 'L', ' ', 'AE1', 'Z',
#         ' ', 'DH', 'EY1', ' ', 'AA1', 'R', ',', ' ', 'W', 'IH1', 'DH', ' ',
#         'P', 'R', 'AA1', 'P', 'ER0', ' ', 'M', 'AE1', 'N', 'AH0', 'JH',
#         'M', 'AH0', 'N', 'T', ',', ' ', 'DH', 'AH0', ' ', 'B', 'IY1', 'N',
#         ' ', 'W', 'IH1', 'L', ' ', 'TH', 'R', 'AH1', 'S', 'T', ' ', 'F',
#         'AO1', 'R', 'TH', ' ', 'IH1', 'T', 'S', ' ', 'R', 'AE1', 'D',
#         'AH0', 'K', 'AH0', 'L', ' ', 'AH0', 'N', 'D', ' ', 'IH1', 'T', 'S',
#         ' ', 'P', 'L', 'UW1', 'M', 'Y', 'UW0', 'AH0', 'L', ';'],
#        dtype='<U3'),
#  array(['HH', 'IY1', ' ', 'K', 'AH0', 'N', 'K', 'L', 'UW1', 'D', 'AH0',
#         'D', ' ', 'DH', 'AE1', 'T', ',', ' ', 'K', 'W', 'OW1', 'T', ',',
#         ' ', 'DH', 'AH0', ' ', 'JH', 'EH1', 'N', 'ER0', 'AH0', 'L', ' ',
#         'R', 'AY1', 'F', 'L', 'IH0', 'NG', ' ', 'K', 'EH2', 'R', 'IH0',
#         'K', 'T', 'ER0', 'IH1', 'S', 'T', 'IH0', 'K', 'S', ' ', 'AH1', 'V',
#         ' ', 'DH', 'AH0', ' ', 'R', 'AY1', 'F', 'AH0', 'L', ' ', 'AA1',
#         'R', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'S', 'EY1', 'M', ' ',
#         'T', 'AY1', 'P', ' ', 'AE1', 'Z', ' ', 'DH', 'OW1', 'Z', ' ', 'F',
#         'AW1', 'N', 'D', ' ', 'AA1', 'N', ' ', 'DH', 'AH0', ' ', 'B',
#         'UH1', 'L', 'AH0', 'T'], dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'EH1', 'L', 'D', 'ER0', ' ', 'HH', 'AE1',
#         'D', ' ', 'T', 'UW1', ' ', 'B', 'IY1', ' ', 'AH0', 'S', 'IH1', 'S',
#         'T', 'AH0', 'D', ' ', 'B', 'AY1', ' ', 'T', 'UW1', ' ', 'B', 'AE1',
#         'NG', 'K', ' ', 'P', 'AO1', 'R', 'T', 'ER0', 'Z', ',', ' ', 'HH',
#         'UW1', ' ', 'K', 'AE1', 'R', 'IY0', 'D', ' ', 'IH1', 'T', ' ', 'F',
#         'AO1', 'R', ' ', 'HH', 'IH1', 'M', ' ', 'T', 'UW1', ' ', 'EY1',
#         ' ', 'K', 'AE1', 'R', 'IH0', 'JH', ' ', 'W', 'EY1', 'T', 'IH0',
#         'NG', ' ', 'N', 'IH1', 'R', ' ', 'DH', 'AH0', ' ', 'M', 'AE1', 'N',
#         'SH', 'AH0', 'N', ' ', 'HH', 'AW1', 'S', '.'], dtype='<U3'),
#  array(['M', 'IH1', 'S', 'T', 'ER0', '.', ' ', 'AA1', 'K', 'S', 'IH0', 'N',
#         'F', 'ER0', 'D', ' ', 'HH', 'AE1', 'V', 'IH0', 'NG', ' ', 'D',
#         'IH0', 'N', 'AY1', 'D', ' ', 'DH', 'AE1', 'T', ' ', 'HH', 'IY1',
#         ' ', 'HH', 'AE1', 'D', ' ', 'M', 'EY1', 'D', ' ', 'EH1', 'N',
#         'IY0', ' ', 'T', 'R', 'AE1', 'N', 'S', 'F', 'ER0', ' ', 'AH1', 'V',
#         ' ', 'S', 'T', 'AA1', 'K', ',', ' ', 'DH', 'AH0', ' ', 'M', 'AE1',
#         'T', 'ER0', ' ', 'W', 'AA1', 'Z', ' ', 'AE1', 'T', ' ', 'W', 'AH1',
#         'N', 'S', ' ', 'P', 'UH1', 'T', ' ', 'IH0', 'N', 'T', 'UW1', ' ',
#         'DH', 'AH0', ' ', 'HH', 'AE1', 'N', 'D', 'Z', ' ', 'AH1', 'V', ' ',
#         'DH', 'AH0', ' ', 'P', 'AH0', 'L', 'IY1', 'S', '.'], dtype='<U3'),
#  array(['HH', 'IY1', ' ', 'F', 'AW1', 'N', 'D', ' ', 'DH', 'EH1', 'M', ' ',
#         'AE1', 'T', ' ', 'L', 'EH1', 'NG', 'K', 'TH', ' ', 'R', 'IH0', 'Z',
#         'AY1', 'D', 'IH0', 'NG', ' ', 'AE1', 'T', ' ', 'DH', 'AH0', ' ',
#         'L', 'AE1', 'T', 'ER0', ' ', 'P', 'L', 'EY1', 'S', ',', ' ', 'W',
#         'AH1', 'N', ' ', 'AE1', 'Z', ' ', 'EY1', ' ', 'L', 'AE1', 'N', 'D',
#         'AH0', 'D', ' ', 'P', 'R', 'AH0', 'P', 'R', 'AY1', 'AH0', 'T',
#         'ER0', ',', ' ', 'DH', 'AH0', ' ', 'AH1', 'DH', 'ER0', ' ', 'AE1',
#         'Z', ' ', 'EY1', ' ', 'P', 'AH1', 'B', 'L', 'IH0', 'K', 'AH0', 'N',
#         '.'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'P', 'R', 'OW1', 'S', 'IY0', 'D', 'Z', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'R', 'AA1', 'B', 'ER0', 'IY0',
#         ' ', 'W', 'ER1', ' ', 'L', 'AA1', 'JH', 'D', ' ', 'IH0', 'N', ' ',
#         'EY1', ' ', 'B', 'AA1', 'S', 'T', 'AH0', 'N', ' ', 'B', 'AE1',
#         'NG', 'K', ','], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'B', 'OY1', ' ', 'D', 'IH0', 'K', 'L', 'EH1',
#         'R', 'D', ' ', 'HH', 'IY1', ' ', 'S', 'AO1', ' ', 'N', 'OW1', ' ',
#         'W', 'AH1', 'N', ',', ' ', 'AH0', 'N', 'D', ' ', 'AH0', 'K', 'AO1',
#         'R', 'D', 'IH0', 'NG', 'L', 'IY0', ' ', 'P', 'AE1', 'S', 'T', ' ',
#         'TH', 'R', 'UW1', ' ', 'W', 'IH0', 'TH', 'AW1', 'T', ' ', 'P',
#         'EY1', 'IH0', 'NG', ' ', 'DH', 'AH0', ' ', 'T', 'OW1', 'L', ' ',
#         'AH1', 'V', ' ', 'EY1', ' ', 'P', 'EH1', 'N', 'IY0', '.'],
#        dtype='<U3'),
#  array(['M', 'IH1', 'S', 'T', 'ER0', '.', ' ', 'B', 'AH1', 'K', 'S', 'T',
#         'AH0', 'N', 'Z', ' ', 'F', 'R', 'EH1', 'N', 'D', 'Z', ' ', 'AE1',
#         'T', ' ', 'W', 'AH1', 'N', 'S', ' ', 'P', 'EY1', 'D', ' ', 'DH',
#         'AH0', ' ', 'F', 'AO1', 'R', 'T', 'IY0', ' ', 'SH', 'IH1', 'L',
#         'IH0', 'NG', 'Z', ',', ' ', 'AH0', 'N', 'D', ' ', 'DH', 'AH0', ' ',
#         'B', 'OY1', ' ', 'W', 'AA1', 'Z', ' ', 'R', 'IY0', 'L', 'IY1', 'S',
#         'T', '.'], dtype='<U3'),
#  array(['W', 'EH1', 'N', ' ', 'EH1', 'N', 'IY0', ' ', 'G', 'IH1', 'V',
#         'AH0', 'N', ' ', 'P', 'R', 'OW1', 'T', 'IH0', 'S', 'T', ' ', 'HH',
#         'AE1', 'Z', ' ', 'T', 'UW1', ' ', 'B', 'IY1', ' ', 'K', 'L', 'AE1',
#         'S', 'AH0', 'F', 'AY2', 'D', ' ', 'DH', 'AH0', ' ', 'K', 'EY1',
#         'S', ' ', 'M', 'AH1', 'S', 'T', ' ', 'B', 'IY1', ' ', 'D', 'IH2',
#         'S', 'AY1', 'D', 'IH0', 'D', ' ', 'AA1', 'N', ' ', 'IH1', 'T', 'S',
#         ' ', 'IH2', 'N', 'D', 'AH0', 'V', 'IH1', 'JH', 'AH0', 'W', 'AH0',
#         'L', ' ', 'M', 'EH1', 'R', 'AH0', 'T', 'S', ';'], dtype='<U3'),
#  array(['AO1', 'Z', 'W', 'AO0', 'L', 'D', 'Z', ' ', 'R', 'IH0', 'V', 'AA1',
#         'L', 'V', 'ER0'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'DH', 'AH0', ' ', 'N', 'UW0', 'T', 'R', 'IH1',
#         'SH', 'AH0', 'N', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'AE1',
#         'N', 'AH0', 'M', 'AH0', 'L', ' ', 'DH', 'AH0', ' ', 'M', 'OW1',
#         'S', 'T', ' ', 'IH0', 'S', 'EH1', 'N', 'SH', 'AH0', 'L', ' ',
#         'AH0', 'N', 'D', ' ', 'K', 'EH2', 'R', 'IH0', 'K', 'T', 'ER0',
#         'IH1', 'S', 'T', 'IH0', 'K', ' ', 'P', 'AA1', 'R', 'T', ' ', 'AH1',
#         'V', ' ', 'DH', 'AH0', ' ', 'F', 'UW1', 'D', ' ', 'S', 'AH0', 'P',
#         'L', 'AY1', ' ', 'IH1', 'Z', ' ', 'D', 'ER0', 'AY1', 'V', 'D', ' ',
#         'F', 'R', 'AH1', 'M', ' ', 'V', 'EH1', 'JH', 'T', 'AH0', 'B',
#         'AH0', 'L'], dtype='<U3'),
#  array(['K', 'AA2', 'R', 'B', 'OW0', 'HH', 'AY1', 'D', 'R', 'EY0', 'T',
#         'S', ' ', '(', 'S', 'T', 'AA1', 'R', 'CH', ',', ' ', 'S', 'EH1',
#         'L', 'Y', 'AH0', 'L', 'OW2', 'S', ')', ' ', 'AH0', 'N', 'D', ' ',
#         'F', 'AE1', 'T', 'S', '.'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'K', 'AA1', 'N', 'S', 'AH0', 'K', 'W', 'AH0', 'N',
#         'S', ' ', 'AH1', 'V', ' ', 'DH', 'IY1', 'Z', ' ', 'D', 'IH0', 'S',
#         'K', 'L', 'OW1', 'ZH', 'ER0', 'Z', ',', ' ', 'B', 'OW1', 'TH', ' ',
#         'B', 'AE1', 'M', 'B', 'R', 'IH0', 'JH', ' ', 'AH0', 'N', 'D', ' ',
#         'HH', 'AH1', 'G', 'IH0', 'N', ',', ' ', 'HH', 'IH1', 'Z', ' ', 'P',
#         'R', 'EH1', 'D', 'AH0', 'S', 'EH2', 'S', 'ER0', ' ', 'IH0', 'N',
#         ' ', 'DH', 'AH0', ' ', 'AO1', 'F', 'AH0', 'S', ',', ' ', 'W',
#         'ER1', ' ', 'K', 'AH0', 'M', 'IH1', 'T', 'IH0', 'D', ' ', 'T',
#         'UW1', ' ', 'N', 'UW1', 'G', 'EY0', 'T', ','], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'R', 'EH1', 'N', 'T', 'AH0', 'L', 'Z', ' ',
#         'AH1', 'V', ' ', 'R', 'UW1', 'M', 'Z', ' ', 'AH0', 'N', 'D', ' ',
#         'F', 'IY1', 'Z', ' ', 'W', 'EH1', 'N', 'T', ' ', 'T', 'UW1', ' ',
#         'DH', 'AH0', ' ', 'W', 'AO1', 'R', 'D', 'AH0', 'N', ',', ' ', 'HH',
#         'UW1', 'Z', ' ', 'IH1', 'N', 'K', 'AH2', 'M', ' ', 'W', 'AA1', 'Z',
#         ' ', 'T', 'UW1', ' ', 'TH', 'AW1', 'Z', 'AH0', 'N', 'D', ' ', 'TH',
#         'R', 'IY1', ' ', 'HH', 'AH1', 'N', 'D', 'R', 'AH0', 'D', ' ', 'S',
#         'EH2', 'V', 'AH0', 'N', 'T', 'EH1', 'F', 'Y', 'UW0', ' ', 'P',
#         'AW1', 'N', 'D', 'Z', '.'], dtype='<U3'),
#  array(['(', 'TH', 'R', 'IY1', ')', ' ', 'HH', 'IH1', 'Z', ' ', 'IH0', 'K',
#         'S', 'P', 'IH1', 'R', 'IY0', 'AH0', 'N', 'S', ' ', 'AH0', 'N', 'D',
#         ' ', 'P', 'R', 'AE1', 'K', 'T', 'IH0', 'S', ' ', 'AE1', 'F', 'T',
#         'ER0', ' ', 'L', 'IY1', 'V', 'IH0', 'NG', ' ', 'DH', 'AH0', ' ',
#         'M', 'ER0', 'IY1', 'N', ' ', 'K', 'AO1', 'R', ',', ' ', 'AH0', 'N',
#         'D', ' ', '(', 'F', 'AO1', 'R', ')', ' ', 'DH', 'AH0', ' ', 'AE1',
#         'K', 'Y', 'ER0', 'AH0', 'S', 'IY0', ' ', 'AH1', 'V', ' ', 'DH',
#         'AH0', ' ', 'W', 'EH1', 'P', 'AH0', 'N', ' ', 'AH0', 'N', 'D', ' ',
#         'DH', 'AH0', ' ', 'K', 'W', 'AA1', 'L', 'AH0', 'T', 'IY0', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'AE2', 'M', 'Y', 'AH0', 'N',
#         'IH1', 'SH', 'AH0', 'N', '.'], dtype='<U3'),
#  array(['W', 'ER1', ' ', 'G', 'AH1', 'V', 'ER0', 'N', 'D', ' ', 'B', 'AY1',
#         ' ', 'R', 'UW1', 'L', 'Z', ' ', 'W', 'IH1', 'CH', ' ', 'DH', 'EY1',
#         ' ', 'DH', 'EH0', 'M', 'S', 'EH1', 'L', 'V', 'Z', ' ', 'HH', 'AE1',
#         'D', ' ', 'F', 'R', 'EY1', 'M', 'D', ',', ' ', 'AH0', 'N', 'D',
#         ' ', 'AH1', 'N', 'D', 'ER0', ' ', 'W', 'IH1', 'CH', ' ', 'S',
#         'AH0', 'B', 'S', 'K', 'R', 'IH1', 'P', 'SH', 'AH0', 'N', 'Z', ' ',
#         'W', 'ER1', ' ', 'L', 'EH1', 'V', 'IY0', 'D'], dtype='<U3'),
#  array(['R', 'AA1', 'N', 'AH0', 'L', 'D', ' ', 'S', 'IH1', 'M', 'AH0', 'N',
#         'Z', ',', ' ', 'CH', 'IY1', 'F', ' ', 'AH1', 'V', ' ', 'DH', 'AH0',
#         ' ', 'Y', 'UW1', 'Z', '.', ' ', 'AA1', 'R', 'M', 'IY0', ' ', 'IH1',
#         'N', 'F', 'AH0', 'N', 'T', 'R', 'IY0', ' ', 'W', 'EH1', 'P', 'AH0',
#         'N', 'Z', ' ', 'IH0', 'V', 'AE2', 'L', 'Y', 'UW0', 'EY1', 'SH',
#         'AH0', 'N', ' ', 'B', 'R', 'AE1', 'N', 'CH', ' ', 'AH1', 'V', ' ',
#         'DH', 'AH0', ' ', 'B', 'AH0', 'L', 'IH1', 'S', 'T', 'IH0', 'K',
#         'S', ' ', 'R', 'IY0', 'S', 'ER1', 'CH', ' ', 'L', 'AE1', 'B', 'R',
#         'AH0', 'T', 'AO2', 'R', 'IY0', ',', ' ', 'S', 'EH1', 'D', ',', ' ',
#         'K', 'W', 'OW1', 'T', ','], dtype='<U3'),
#  array(['Y', 'EH1', 'T', ' ', 'DH', 'AH0', ' ', 'P', 'AH1', 'B', 'L',
#         'IH0', 'K', ' ', 'AH0', 'P', 'IH1', 'N', 'Y', 'AH0', 'N', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'HH', 'OW1', 'L', ' ', 'B',
#         'AA1', 'D', 'IY0', ' ', 'S', 'IY1', 'M', 'Z', ' ', 'T', 'UW1', ' ',
#         'HH', 'AE1', 'V', ' ', 'CH', 'EH1', 'K', 'T', ' ', 'D', 'IH2', 'S',
#         'IH0', 'P', 'EY1', 'SH', 'AH0', 'N', '.'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'P', 'UW1', 'R', 'ER0', ' ', 'P', 'R', 'IH1',
#         'Z', 'AH0', 'N', 'ER0', 'Z', ' ', 'W', 'ER1', ' ', 'N', 'AA1', 'T',
#         ' ', 'IH0', 'N', ' ', 'AE1', 'B', 'JH', 'EH0', 'K', 'T', ' ', 'W',
#         'AA1', 'N', 'T', ',', ' ', 'AE1', 'Z', ' ', 'IH0', 'N', ' ', 'AH1',
#         'DH', 'ER0', ' ', 'P', 'R', 'IH1', 'Z', 'AH0', 'N', 'Z', ','],
#        dtype='<U3'),
#  array(['DH', 'IH1', 'S', ' ', 'S', 'IY1', 'M', 'Z', ' ', 'T', 'UW1', ' ',
#         'HH', 'AE1', 'V', ' ', 'D', 'IH2', 'S', 'AY1', 'D', 'IH0', 'D',
#         ' ', 'K', 'AO2', 'R', 'V', 'OY1', 'S', 'ER0', 'IY0', ','],
#        dtype='<U3'),
#  array(['IH1', 'T', ' ', 'JH', 'AH1', 'S', 'T', ' ', 'IH1', 'Z', ' ',
#         'AE1', 'N', ' ', 'EY1', 'D', ' ', 'IH0', 'N', ' ', 'S', 'IY1',
#         'IH0', 'NG', ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ', 'F', 'AE1',
#         'K', 'T', ' ', 'DH', 'AE1', 'T', ' ', 'Y', 'UW1', ' ', 'OW1', 'N',
#         'L', 'IY0', ' ', 'HH', 'AE1', 'V', ' ', 'DH', 'AH0', ' ', 'W',
#         'AH1', 'N', ' ', 'EH1', 'L', 'AH0', 'M', 'AH0', 'N', 'T', ',', ' ',
#         'DH', 'AH0', ' ', 'K', 'R', 'AA1', 'SH', 'ER0', ','], dtype='<U3'),
#  array(['DH', 'IH1', 'S', ' ', 'IH1', 'Z', ' ', 'EY1', ' ', 'D', 'EH1',
#         'F', 'AH0', 'N', 'AH0', 'T', ' ', 'AE0', 'D', 'V', 'AE1', 'N', 'T',
#         'IH0', 'JH', ' ', 'T', 'UW1', ' ', 'DH', 'AH0', ' ', 'SH', 'UW1',
#         'T', 'ER0', ',', ' ', 'DH', 'AH0', ' ', 'V', 'IY1', 'HH', 'IH0',
#         'K', 'AH0', 'L', ' ', 'M', 'UW1', 'V', 'IH0', 'NG', ' ', 'D',
#         'ER0', 'EH1', 'K', 'T', 'L', 'IY0', ' ', 'AH0', 'W', 'EY1', ' ',
#         'F', 'R', 'AH1', 'M', ' ', 'HH', 'IH1', 'M', ' ', 'AH0', 'N', 'D',
#         ' ', 'DH', 'AH0', ' ', 'D', 'AW1', 'N', 'G', 'R', 'EY1', 'D', ' ',
#         'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'S', 'T', 'R', 'IY1', 'T', ',',
#         ' ', 'AH0', 'N', 'D', ' ', 'HH', 'IY1', ' ', 'B', 'IY1', 'IH0',
#         'NG', ' ', 'IH0', 'N', ' ', 'AE1', 'N', ' ', 'EH1', 'L', 'AH0',
#         'V', 'EY2', 'T', 'IH0', 'D', ' ', 'P', 'AH0', 'Z', 'IH1', 'SH',
#         'AH0', 'N'], dtype='<U3'),
#  array(['IH1', 'T', ' ', 'IH1', 'Z', ' ', 'K', 'L', 'IH1', 'R', ' ', 'DH',
#         'AE1', 'T', ' ', 'DH', 'EH1', 'R', ' ', 'AA1', 'R', ' ', 'AH1',
#         'P', 'W', 'ER0', 'D', ' ', 'AH0', 'N', 'D', ' ', 'D', 'AW1', 'N',
#         'W', 'ER0', 'D', ' ', 'K', 'ER1', 'AH0', 'N', 'T', 'S', ' ', 'AH1',
#         'V', ' ', 'W', 'AO1', 'T', 'ER0', ' ', 'K', 'AH0', 'N', 'T', 'EY1',
#         'N', 'IH0', 'NG', ' ', 'F', 'UW1', 'D', ' ', '(', 'K', 'AA1', 'M',
#         'P', 'ER0', 'AH0', 'B', 'AH0', 'L', ' ', 'T', 'UW1', ' ', 'B', 'L',
#         'AH1', 'D', ' ', 'AH1', 'V', ' ', 'AE1', 'N', ' ', 'AE1', 'N',
#         'AH0', 'M', 'AH0', 'L', ')', ','], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'L', 'AE1', 'T', 'ER0', ' ', 'R', 'EY1', 'Z',
#         'D', ' ', 'EY0', 'T', 'IY1', 'N', ' ', 'P', 'EH1', 'N', 'S', ' ',
#         'AH0', 'M', 'AH1', 'NG', ' ', 'DH', 'EH1', 'M', ' ', 'T', 'UW1',
#         ' ', 'P', 'EY1', ' ', 'F', 'AO1', 'R', ' ', 'EY1', ' ', 'T', 'R',
#         'AH1', 'S', ' ', 'AH1', 'V', ' ', 'S', 'T', 'R', 'AO1', ' ', 'F',
#         'AO1', 'R', ' ', 'DH', 'AH0', ' ', 'P', 'UW1', 'R', ' ', 'W',
#         'UH1', 'M', 'AH0', 'N', ' ', 'T', 'UW1', ' ', 'L', 'AY1', ' ',
#         'AA1', 'N', '.'], dtype='<U3'),
#  array(['HH', 'IY1', ' ', 'HH', 'AE1', 'D', ' ', 'HH', 'AY1', ' ', 'M',
#         'OW2', 'T', 'AH0', 'V', 'EY1', 'SH', 'AH0', 'N', '.', ' ', 'HH',
#         'IY1', ' ', 'HH', 'AE1', 'D', ' ', 'P', 'R', 'AH0', 'Z', 'UW1',
#         'M', 'AH0', 'B', 'L', 'IY0', ' ', 'EY1', ' ', 'G', 'UH1', 'D', ' ',
#         'T', 'UW1', ' ', 'EH1', 'K', 'S', 'AH0', 'L', 'AH0', 'N', 'T', ' ',
#         'R', 'AY1', 'F', 'AH0', 'L', ' ', 'AH0', 'N', 'D', ' ', 'G', 'UH1',
#         'D', ' ', 'AE2', 'M', 'Y', 'AH0', 'N', 'IH1', 'SH', 'AH0', 'N',
#         '.'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'HH', 'IH1', 'Z', ' ', 'EH1', 'V', 'AH0', 'D',
#         'AH0', 'N', 'S', ' ', 'IH0', 'N', ' ', 'EY0', 'T', 'IY1', 'N', ' ',
#         'F', 'AO1', 'R', 'T', 'IY1', 'N', ',', ' ', 'S', 'EH1', 'D', ' ',
#         'IH1', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'M', 'AO1', 'R', ','],
#        dtype='<U3'),
#  array(['AH0', 'N', 'D', ' ', 'G', 'EY1', 'V', ' ', 'DH', 'AH0', ' ', 'G',
#         'AA1', 'R', 'N', 'IH0', 'SH', ' ', 'F', 'AO1', 'R', ' ', 'DH',
#         'AH0', ' ', 'K', 'AA1', 'M', 'AH0', 'N', ' ', 'S', 'AY1', 'D', ' ',
#         'AE1', 'T', ' ', 'DH', 'AE1', 'T', ' ', 'S', 'AH1', 'M', ',', ' ',
#         'W', 'IH1', 'CH', ' ', 'IH1', 'Z', ' ', 'F', 'AY1', 'V', ' ', 'SH',
#         'IH1', 'L', 'IH0', 'NG', 'Z', ' ', 'M', 'AO1', 'R', ' ', 'DH',
#         'AE1', 'N', ' ', 'M', 'IH1', 'S', 'T', 'ER0', '.', ' ', 'N', 'IY1',
#         'L', 'D', ' ', 'S', 'EH1', 'Z', ' ', 'W', 'AA1', 'Z', ' ', 'EH0',
#         'K', 'S', 'T', 'AO1', 'R', 'T', 'IH0', 'D', ' ', 'AA1', 'N', ' ',
#         'DH', 'AH0', ' ', 'K', 'AA1', 'M', 'AH0', 'N', ' ', 'S', 'AY1',
#         'D', '.'], dtype='<U3'),
#  array(['DH', 'AE1', 'T', ' ', 'AO1', 'Z', 'W', 'AO0', 'L', 'D', ' ', 'W',
#         'AA1', 'Z', ' ', 'EY1', ' ', 'G', 'UH1', 'D', ' ', 'SH', 'AA1',
#         'T', ',', ' ', 'S', 'AH1', 'M', 'W', 'AH1', 'T', ' ', 'B', 'EH1',
#         'T', 'ER0', ' ', 'DH', 'AE1', 'N', ' ', 'AO1', 'R', ' ', 'IY1',
#         'K', 'W', 'AH0', 'L', ' ', 'T', 'UW1', ' ', '-', '-', 'EH1', 'T',
#         'ER0', ' ', 'DH', 'AE1', 'N', ' ', 'DH', 'AH0', ' ', 'AE1', 'V',
#         'ER0', 'IH0', 'JH', ' ', 'L', 'EH1', 'T', ' ', 'AH1', 'S', ' ',
#         'S', 'EY1', '.'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'DH', 'AH0', ' ', 'P', 'L', 'AE1', 'N', 'T', ' ',
#         'AE1', 'Z', ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ', 'AE1', 'N',
#         'AH0', 'M', 'AH0', 'L', ' ', 'M', 'AH0', 'T', 'AE1', 'B', 'AH0',
#         'L', 'IH2', 'Z', 'AH0', 'M', ' ', 'M', 'AH1', 'S', 'T', ' ', 'K',
#         'AH0', 'N', 'S', 'IH1', 'S', 'T', ' ', 'AH1', 'V', ' ', 'AE2', 'N',
#         'AH0', 'B', 'AA1', 'L', 'IH0', 'K', ' ', 'AH0', 'N', 'D', ' ', 'K',
#         'AE2', 'T', 'AH0', 'B', 'AA1', 'L', 'IH0', 'K', ' ', 'P', 'R',
#         'AA1', 'S', 'EH0', 'S', 'AH0', 'Z', '.'], dtype='<U3'),
#  array(['W', 'AO1', 'T', 'ER0', ' ', 'W', 'IH1', 'CH', ' ', 'IH1', 'Z',
#         ' ', 'L', 'AO1', 'S', 'T', ' ', 'B', 'AY1', ' ', 'IH0', 'V', 'AE2',
#         'P', 'ER0', 'EY1', 'SH', 'AH0', 'N', ',', ' ', 'AH0', 'S', 'P',
#         'EH1', 'SH', 'L', 'IY0', ' ', 'F', 'R', 'AH1', 'M', ' ', 'DH',
#         'AH0', ' ', 'L', 'IY1', 'F', ' ', 'S', 'ER1', 'F', 'AH0', 'S', ' ',
#         'TH', 'R', 'UW1', ' ', 'DH', 'AH0', ' ', 'S', 'T', 'OW1', 'M',
#         'AH0', 'T', 'AH0', ';'], dtype='<U3'),
#  array(['AO1', 'Z', 'W', 'AO0', 'L', 'D', ' ', 'AH0', 'B', 'T', 'EY1', 'N',
#         'D', ' ', 'EY1', ' ', 'HH', 'AH1', 'N', 'T', 'IH0', 'NG', ' ', 'L',
#         'AY1', 'S', 'AH0', 'N', 'S', ',', ' ', 'JH', 'OY1', 'N', 'D', ' ',
#         'EY1', ' ', 'HH', 'AH1', 'N', 'T', 'IH0', 'NG', ' ', 'K', 'L',
#         'AH1', 'B', ' ', 'AH0', 'N', 'D', ' ', 'W', 'EH1', 'N', 'T', ' ',
#         'HH', 'AH1', 'N', 'T', 'IH0', 'NG', ' ', 'AH0', 'B', 'AW1', 'T',
#         ' ', 'S', 'IH1', 'K', 'S', ' ', 'T', 'AY1', 'M', 'Z', ',', ' ',
#         'AE1', 'Z', ' ', 'D', 'IH0', 'S', 'K', 'AH1', 'S', 'T', ' ', 'M',
#         'AO1', 'R', ' ', 'F', 'UH1', 'L', 'IY0', ' ', 'IH0', 'N', ' ',
#         'CH', 'AE1', 'P', 'T', 'ER0', ' ', 'S', 'IH1', 'K', 'S', '.'],
#        dtype='<U3'),
#  array(['IH0', 'G', 'Z', 'AE2', 'M', 'AH0', 'N', 'EY1', 'SH', 'AH0', 'N',
#         ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'K', 'AA1', 'R', 'T', 'R',
#         'AH0', 'JH', ' ', 'K', 'EY1', 'S', 'AH0', 'Z', ' ', 'F', 'AW1',
#         'N', 'D', ' ', 'AA1', 'N', ' ', 'DH', 'AH0', ' ', 'S', 'IH1', 'K',
#         'S', 'TH', ' ', 'F', 'L', 'AO1', 'R', ' ', 'AH1', 'V', ' ', 'DH',
#         'AH0', ' ', 'D', 'IH0', 'P', 'AA1', 'Z', 'AH0', 'T', 'AO2', 'R',
#         'IY0', ' ', 'B', 'IH1', 'L', 'D', 'IH0', 'NG'], dtype='<U3'),
#  array(['F', 'AO1', 'R', ' ', 'P', 'OY1', 'N', 'T', ' ', 'EY1', 'T', ' ',
#         'T', 'UW1', ' ', 'F', 'AY1', 'V', ' ', 'P', 'OY1', 'N', 'T', ' ',
#         'S', 'IH1', 'K', 'S', ' ', 'S', 'EH1', 'K', 'AH0', 'N', 'D', 'Z',
#         ' ', 'IH1', 'F', ' ', 'DH', 'AH0', ' ', 'S', 'EH1', 'K', 'AH0',
#         'N', 'D', ' ', 'SH', 'AA1', 'T', ' ', 'M', 'IH1', 'S', 'T', ','],
#        dtype='<U3'),
#  array(['IH0', 'N', ' ', 'AO1', 'L', ' ', 'DH', 'IY1', 'Z', ' ', 'L',
#         'AY1', 'N', 'Z', ' ', 'DH', 'AH0', ' ', 'F', 'AE1', 'K', 'T', 'S',
#         ' ', 'AA1', 'R', ' ', 'D', 'R', 'AO1', 'N', ' ', 'T', 'AH0', 'G',
#         'EH1', 'DH', 'ER0', ' ', 'B', 'AY1', ' ', 'EY1', ' ', 'S', 'T',
#         'R', 'AO1', 'NG', ' ', 'TH', 'R', 'EH1', 'D', ' ', 'AH1', 'V', ' ',
#         'Y', 'UW1', 'N', 'AH0', 'T', 'IY0', '.'], dtype='<U3'),
#  array(['DH', 'IH1', 'S', ' ', 'W', 'AA1', 'Z', ' ', 'D', 'EH0', 'L',
#         'AA1', 'R', 'IY0', 'UW0', ' ', 'W', 'AA1', 'CH', ',', ' ', 'F',
#         'UH1', 'L', 'IY0', ' ', 'AY0', 'D', 'EH1', 'N', 'T', 'AH0', 'F',
#         'AY2', 'D', ' ', 'AE1', 'Z', ' ', 'S', 'AH1', 'CH', ',', ' ', 'W',
#         'IH1', 'CH', ' ', 'HH', 'AA1', 'K', 'ER0', ' ', 'T', 'OW1', 'L',
#         'D', ' ', 'HH', 'IH1', 'Z', ' ', 'B', 'R', 'AH1', 'DH', 'ER0', ' ',
#         'D', 'EH0', 'L', 'AA1', 'R', 'IY0', 'UW0', ' ', 'HH', 'AE1', 'D',
#         ' ', 'G', 'IH1', 'V', 'AH0', 'N', ' ', 'HH', 'IH1', 'M', ' ', 'DH',
#         'AH0', ' ', 'M', 'AO1', 'R', 'N', 'IH0', 'NG', ' ', 'AH1', 'V',
#         ' ', 'DH', 'AH0', ' ', 'M', 'ER1', 'D', 'ER0', '.'], dtype='<U3'),
#  array(['DH', 'AE1', 'T', ' ', 'N', 'AA1', 'T', ' ', 'M', 'AO1', 'R', ' ',
#         'DH', 'AE1', 'N', ' ', 'W', 'AH1', 'N', ' ', 'B', 'AA1', 'T',
#         'AH0', 'L', ' ', 'AH1', 'V', ' ', 'W', 'AY1', 'N', ' ', 'AO1', 'R',
#         ' ', 'W', 'AH1', 'N', ' ', 'K', 'W', 'AO1', 'R', 'T', ' ', 'AH1',
#         'V', ' ', 'B', 'IH1', 'R', ' ', 'K', 'UH1', 'D', ' ', 'B', 'IY1',
#         ' ', 'IH1', 'SH', 'UW0', 'D', ' ', 'AE1', 'T', ' ', 'W', 'AH1',
#         'N', ' ', 'T', 'AY1', 'M', '.', ' ', 'N', 'OW1', ' ', 'AH0', 'K',
#         'AW1', 'N', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'T', 'EY1', 'K', 'AH0',
#         'N', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'AH0', 'M', 'AW1',
#         'N', 'T', ' ', 'AH1', 'V', ' ', 'L', 'IH1', 'K', 'ER0', 'Z', ' ',
#         'AH0', 'D', 'M', 'IH1', 'T', 'AH0', 'D', ' ', 'IH0', 'N', ' ', 'W',
#         'AH1', 'N', ' ', 'D', 'EY1', ','], dtype='<U3'),
#  array(['HH', 'IY1', ' ', 'HH', 'AE1', 'D', ' ', 'EY1', ' ', 'T', 'OW1',
#         'T', 'AH0', 'L', ' ', 'AH1', 'V', ' ', 'B', 'IH0', 'T', 'W', 'IY1',
#         'N', ' ', 'F', 'AO1', 'R', ' ', 'P', 'OY1', 'N', 'T', ' ', 'EY1',
#         'T', ' ', 'AH0', 'N', 'D', ' ', 'F', 'AY1', 'V', ' ', 'P', 'OY1',
#         'N', 'T', ' ', 'S', 'IH1', 'K', 'S', ' ', 'S', 'EH1', 'K', 'AH0',
#         'N', 'D', 'Z', ' ', 'B', 'IH0', 'T', 'W', 'IY1', 'N', ' ', 'DH',
#         'AH0', ' ', 'T', 'UW1', ' ', 'SH', 'AA1', 'T', 'S', ' ', 'W',
#         'IH1', 'CH', ' ', 'HH', 'IH1', 'T'], dtype='<U3'),
#  array(['AO2', 'L', 'DH', 'OW1', ' ', 'AO1', 'L', ' ', 'AH1', 'V', ' ',
#         'DH', 'AH0', ' ', 'SH', 'AA1', 'T', 'S', ' ', 'W', 'ER1', ' ',
#         'EY1', ' ', 'F', 'Y', 'UW1', ' ', 'IH1', 'N', 'CH', 'AH0', 'Z',
#         ' ', 'HH', 'AY1', ' ', 'AH0', 'N', 'D', ' ', 'T', 'UW1', ' ', 'DH',
#         'AH0', ' ', 'R', 'AY1', 'T', ' ', 'AH1', 'V', ' ', 'DH', 'AH0',
#         ' ', 'T', 'AA1', 'R', 'G', 'AH0', 'T', ','], dtype='<U3'),
#  array(['W', 'IH1', 'DH', ' ', 'T', 'UW1', ' ', 'HH', 'IH1', 'T', 'S', ',',
#         ' ', 'W', 'IH0', 'DH', 'IH1', 'N', ' ', 'F', 'AO1', 'R', ' ', 'P',
#         'OY1', 'N', 'T', ' ', 'EY1', 'T', ' ', 'AH0', 'N', 'D', ' ', 'F',
#         'AY1', 'V', ' ', 'P', 'OY1', 'N', 'T', ' ', 'S', 'IH1', 'K', 'S',
#         ' ', 'S', 'EH1', 'K', 'AH0', 'N', 'D', 'Z', '.'], dtype='<U3'),
#  array(['D', 'IH0', 'S', 'K', 'AH1', 'V', 'ER0', 'IY0', ' ', 'AH1', 'V',
#         ' ', 'DH', 'AH0', ' ', 'M', 'ER1', 'D', 'ER0', ' ', 'K', 'EY1',
#         'M', ' ', 'IH0', 'N', ' ', 'DH', 'IH1', 'S', ' ', 'W', 'AY1', 'Z',
#         '.', ' ', 'OW0', 'K', 'AA1', 'N', 'ER0', ',', ' ', 'EY1', ' ', 'P',
#         'AH1', 'NG', 'K', 'CH', 'UW0', 'AH0', 'L', ' ', 'AH0', 'N', 'D',
#         ' ', 'W', 'EH1', 'L', 'AH0', 'N', 'K', 'AH0', 'D', 'AH0', 'K', 'T',
#         'IH0', 'D', ' ', 'AH0', 'F', 'IH1', 'SH', 'AH0', 'L', ',', ' ',
#         'W', 'AA1', 'Z', ' ', 'AE1', 'T', ' ', 'W', 'AH1', 'N', 'S', ' ',
#         'M', 'IH1', 'S', 'T', ' ', 'AE1', 'T', ' ', 'DH', 'AH0', ' ', 'L',
#         'AH1', 'N', 'D', 'AH0', 'N', ' ', 'D', 'AA1', 'K', 'S', '.'],
#        dtype='<U3'),
#  array(['IH0', 'N', ' ', 'W', 'AH1', 'N', ',', ' ', 'F', 'AO1', 'R', ' ',
#         'S', 'EH1', 'V', 'AH0', 'N', ' ', 'Y', 'IH1', 'R', 'Z', ' ', '-',
#         '-', 'AE1', 'T', ' ', 'AH1', 'V', ' ', 'EY1', ' ', 'M', 'AE1', 'N',
#         ' ', 'S', 'EH1', 'N', 'T', 'AH0', 'N', 'S', 'T', ' ', 'T', 'UW1',
#         ' ', 'D', 'EH1', 'TH', ',', ' ', 'F', 'AO1', 'R', ' ', 'HH', 'UW1',
#         'M', ' ', 'G', 'R', 'EY1', 'T', ' ', 'IH1', 'N', 'T', 'AH0', 'R',
#         'EH2', 'S', 'T', ' ', 'HH', 'AE1', 'D', ' ', 'B', 'IH1', 'N', ' ',
#         'M', 'EY1', 'D', ',', ' ', 'B', 'AH1', 'T', ' ', 'HH', 'UW1', 'M',
#         ' ', 'IH1', 'T', ' ', 'W', 'AA1', 'Z', ' ', 'N', 'AA1', 'T', ' ',
#         'TH', 'AO1', 'T', ' ', 'R', 'AY1', 'T', ' ', 'T', 'UW1', ' ', 'P',
#         'AA1', 'R', 'D', 'AH0', 'N', '.'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'K', 'AH0', 'M', 'IH1', 'SH', 'AH0', 'N', ' ',
#         'IH1', 'Z', ' ', 'N', 'AA1', 'T', ' ', 'EY1', 'B', 'AH0', 'L', ' ',
#         'T', 'UW1', ' ', 'R', 'IY1', 'CH', ' ', 'EH1', 'N', 'IY0', ' ',
#         'D', 'EH1', 'F', 'AH0', 'N', 'AH0', 'T', ' ', 'K', 'AH0', 'N', 'K',
#         'L', 'UW1', 'ZH', 'AH0', 'N', 'Z', ' ', 'AE1', 'Z', ' ', 'T',
#         'UW1', ' ', 'W', 'EH1', 'DH', 'ER0', ' ', 'AO1', 'R', ' ', 'N',
#         'AA1', 'T', ' ', 'HH', 'IY1', ' ', 'W', 'AA1', 'Z', ',', ' ', 'K',
#         'W', 'OW1', 'T', ',', ' ', 'S', 'EY1', 'N', ',', ' ', 'AH1', 'N',
#         'K', 'W', 'OW1', 'T', ',', ' ', 'AH1', 'N', 'D', 'ER0', ' ', 'P',
#         'R', 'IH0', 'V', 'EY1', 'L', 'IH0', 'NG', ' ', 'L', 'IY1', 'G',
#         'AH0', 'L', ' ', 'S', 'T', 'AE1', 'N', 'D', 'ER0', 'D', 'Z', '.'],
#        dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'P', 'R', 'IH1', 'Z', 'AH0', 'N', 'ER0', 'Z',
#         ' ', 'W', 'ER1', ' ', 'IH0', 'N', ' ', 'D', 'UW1', ' ', 'K', 'AO1',
#         'R', 'S', ' ', 'T', 'R', 'AE0', 'N', 'S', 'F', 'ER1', 'D', ' ',
#         'T', 'UW1', ' ', 'N', 'UW1', 'G', 'EY0', 'T', ',', ' ', 'T', 'UW1',
#         ' ', 'B', 'IY1', ' ', 'P', 'UH1', 'T', ' ', 'AH0', 'P', 'AA1', 'N',
#         ' ', 'DH', 'EH1', 'R', ' ', 'T', 'R', 'AY1', 'AH0', 'L', ' ',
#         'AE1', 'T', ' ', 'DH', 'AH0', ' ', 'S', 'EH1', 'N', 'T', 'R',
#         'AH0', 'L', ' ', 'K', 'R', 'IH1', 'M', 'AH0', 'N', 'AH0', 'L', ' ',
#         'K', 'AO1', 'R', 'T', '.'], dtype='<U3'),
#  array(['HH', 'ER1', ' ', 'HH', 'EH1', 'R', ' ', 'W', 'AA1', 'Z', ' ', 'D',
#         'R', 'EH1', 'S', 'T', ' ', 'IH0', 'N', ' ', 'L', 'AO1', 'NG', ' ',
#         'K', 'R', 'EY1', 'P', ' ', 'B', 'AE1', 'N', 'D', 'Z', '.', ' ',
#         'SH', 'IY1', ' ', 'HH', 'AE1', 'D', ' ', 'L', 'EY1', 'S', ' ', 'R',
#         'AH1', 'F', 'AH0', 'L', 'Z', ' ', 'AE1', 'T', ' ', 'HH', 'ER1',
#         ' ', 'R', 'IH1', 'S', 'T', ',', ' ', 'AH0', 'N', 'D', ' ', 'W',
#         'AO1', 'R', ' ', 'P', 'R', 'AY2', 'M', 'ER0', 'S', 'OW0', 'L',
#         'EH1', 'R', 'JH', ' ', 'K', 'IH1', 'D', ' ', 'G', 'L', 'AH1', 'V',
#         'Z', '.'], dtype='<U3'),
#  array(['HH', 'IY1', ' ', 'S', 'L', 'EH1', 'P', 'T', ' ', 'IH0', 'N', ' ',
#         'DH', 'AH0', ' ', 'S', 'EY1', 'M', ' ', 'B', 'EH1', 'D', ' ', 'W',
#         'IH1', 'DH', ' ', 'EY1', ' ', 'HH', 'AY1', 'W', 'M', 'AY2', 'N',
#         ' ', 'AA1', 'N', ' ', 'W', 'AH1', 'N', ' ', 'S', 'AY1', 'D', ',',
#         ' ', 'AH0', 'N', 'D', ' ', 'EY1', ' ', 'M', 'AE1', 'N', ' ', 'CH',
#         'AA1', 'R', 'JH', 'D', ' ', 'W', 'IH1', 'DH', ' ', 'M', 'ER1', 'D',
#         'ER0', ' ', 'AA1', 'N', ' ', 'DH', 'AH0', ' ', 'AH1', 'DH', 'ER0',
#         '.'], dtype='<U3'),
#  array(['W', 'AA1', 'Z', ' ', 'S', 'T', 'R', 'UW1', 'N', ' ', 'IH0', 'N',
#         ' ', 'F', 'R', 'AH1', 'N', 'T', ' ', 'AH1', 'V', ' ', 'DH', 'AH0',
#         ' ', 'D', 'AA1', 'K', ',', ' ', 'AH0', 'N', 'D', ' ', 'S', 'P',
#         'R', 'IH1', 'NG', 'K', 'AH0', 'L', 'D', ' ', 'IH1', 'T', ' ', 'T',
#         'AH0', 'W', 'AO1', 'R', 'D', 'Z', ' ', 'DH', 'AH0', ' ', 'B',
#         'EH1', 'N', 'CH', ' ', 'W', 'IH1', 'DH', ' ', 'EY1', ' ', 'K',
# ...
#  array(['L', 'EY1', 'T', 'ER0', ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ',
#         'D', 'EY1', ' ', 'IY1', 'CH', ' ', 'W', 'UH1', 'M', 'AH0', 'N',
#         ' ', 'F', 'AW1', 'N', 'D', ' ', 'AE1', 'N', ' ', 'EH1', 'M', 'P',
#         'T', 'IY0', ' ', 'SH', 'EH1', 'L', ' ', 'AA1', 'N', ' ', 'DH',
#         'AH0', ' ', 'G', 'R', 'AW1', 'N', 'D', ' ', 'N', 'IH1', 'R', ' ',
#         'DH', 'AH0', ' ', 'HH', 'AW1', 'S', '.', ' ', 'DH', 'IY1', 'Z',
#         ' ', 'T', 'UW1', ' ', 'SH', 'EH1', 'L', 'Z', ' ', 'W', 'ER1', ' ',
#         'D', 'IH0', 'L', 'IH1', 'V', 'ER0', 'D', ' ', 'T', 'UW1', ' ',
#         'DH', 'AH0', ' ', 'P', 'AH0', 'L', 'IY1', 'S', '.'], dtype='<U3'),
#  array(['AA1', 'N', ' ', 'D', 'IH0', 'S', 'EH1', 'M', 'B', 'ER0', ' ', 'T',
#         'W', 'EH2', 'N', 'T', 'IY0', 'S', 'K', 'AY1', 'Z', ',', ' ', 'N',
#         'AY1', 'N', 'T', 'IY1', 'N', ' ', 'S', 'IH1', 'K', 'S', 'T', 'R',
#         'AY2', 'TH', ',', ' ', 'DH', 'AH0', ' ', 'EH1', 'F', 'B', 'IY1',
#         'AY1', ' ', 'S', 'ER1', 'K', 'Y', 'AH0', 'L', 'EY2', 'T', 'AH0',
#         'D', ' ', 'AH0', 'D', 'IH1', 'SH', 'AH0', 'N', 'AH0', 'L', ' ',
#         'IH2', 'N', 'S', 'T', 'R', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z', ' ',
#         'T', 'UW1', ' ', 'AO1', 'L', ' ', 'IH1', 'T', 'S', ' ', 'EY1',
#         'JH', 'AH0', 'N', 'T', 'S', ','], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'EY0', 'T', 'IY1', 'N', ' ', 'T', 'W', 'EH1', 'N',
#         'T', 'IY0', 'N', 'AY2', ' ', 'DH', 'AH0', ' ', 'G', 'AE1', 'L',
#         'OW0', 'Z', ' ', 'K', 'L', 'EY1', 'M', 'D', ' ', 'T', 'UW1', ' ',
#         'M', 'AO1', 'R', ' ', 'V', 'IH1', 'K', 'T', 'IH0', 'M', 'Z', ' ',
#         'F', 'AO1', 'R', ' ', 'DH', 'IH1', 'S', ' ', 'AH0', 'F', 'EH1',
#         'N', 'S', '.'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'S', 'IY1', 'K', 'R', 'AH0', 'T', ' ', 'S',
#         'ER1', 'V', 'AH0', 'S', ' ', 'HH', 'AE1', 'D', ' ', 'R', 'AH0',
#         'S', 'IY1', 'V', 'D', ' ', 'F', 'R', 'AH1', 'M', ' ', 'DH', 'AH0',
#         ' ', 'EH1', 'F', 'B', 'IY1', 'AY1', ' ', 'S', 'AH1', 'M', ' ', 'N',
#         'AY1', 'N', ' ', 'TH', 'AW1', 'Z', 'AH0', 'N', 'D', ' ', 'R',
#         'IH0', 'P', 'AO1', 'R', 'T', 'S', ' ', 'AA1', 'N', ' ', 'M', 'EH1',
#         'M', 'B', 'ER0', 'Z', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'K',
#         'AA1', 'M', 'Y', 'AH0', 'N', 'AH0', 'S', 'T', ' ', 'P', 'AA1', 'R',
#         'T', 'IY0', '.'], dtype='<U3'),
#  array(['AO1', 'R', ',', ' ', 'K', 'W', 'OW1', 'T', ',', ' ', 'AH1', 'DH',
#         'ER0', ' ', 'HH', 'AY1', ' ', 'G', 'AH1', 'V', 'ER0', 'N', 'M',
#         'AH0', 'N', 'T', ' ', 'AH0', 'F', 'IH1', 'SH', 'AH0', 'L', 'Z',
#         ' ', 'IH0', 'N', ' ', 'DH', 'AH0', ' ', 'N', 'EY1', 'CH', 'ER0',
#         ' ', 'AH1', 'V', ' ', 'EY1', ' ', 'K', 'AH0', 'M', 'P', 'L', 'EY1',
#         'N', 'T', ' ', 'K', 'AH1', 'P', 'AH0', 'L', 'D', ' ', 'W', 'IH1',
#         'DH', ' ', 'AE1', 'N', ' ', 'IH0', 'K', 'S', 'P', 'R', 'EH1', 'S',
#         'T', ' ', 'AO1', 'R', ' ', 'IH2', 'M', 'P', 'L', 'AY1', 'D', ' ',
#         'D', 'IH0', 'T', 'ER2', 'M', 'AH0', 'N', 'EY1', 'SH', 'AH0', 'N',
#         ' ', 'T', 'UW1', ' ', 'Y', 'UW1', 'S', ' ', 'EY1', ' ', 'M', 'IY1',
#         'N', 'Z', ','], dtype='<U3'),
#  array(['DH', 'EY1', ' ', 'S', 'IY1', 'M', ' ', 'AH0', 'N', 'D', 'UW1',
#         'L', 'IY0', ' ', 'R', 'IY0', 'S', 'T', 'R', 'IH1', 'K', 'T', 'IH0',
#         'V', ' ', 'IH0', 'N', ' ', 'K', 'AH0', 'N', 'T', 'IH1', 'N', 'Y',
#         'UW0', 'IH0', 'NG', ' ', 'T', 'UW1', ' ', 'R', 'IY2', 'K', 'W',
#         'AY1', 'ER0', ' ', 'S', 'AH1', 'M', ' ', 'M', 'AE2', 'N', 'AH0',
#         'F', 'EH0', 'S', 'T', 'EY1', 'SH', 'AH0', 'N', ' ', 'AH1', 'V',
#         ' ', 'AE1', 'N', 'IH0', 'M', 'AH0', 'S', ' ', 'AH0', 'G', 'EH1',
#         'N', 'S', 'T', ' ', 'EY1', ' ', 'G', 'AH1', 'V', 'ER0', 'N', 'M',
#         'AH0', 'N', 'T', ' ', 'AH0', 'F', 'IH1', 'SH', 'AH0', 'L', '.'],
#        dtype='<U3'),
#  array(['DH', 'EH1', 'R', ' ', 'W', 'ER1', ' ', 'AE1', 'T', ' ', 'DH',
#         'AH0', ' ', 'M', 'OW1', 'M', 'AH0', 'N', 'T', ' ', 'IH0', 'N', ' ',
#         'N', 'UW1', 'G', 'EY0', 'T', ' ', 'S', 'IH1', 'K', 'S', ' ', 'K',
#         'AA1', 'N', 'V', 'IH0', 'K', 'T', 'S', ' ', 'S', 'EH1', 'N', 'T',
#         'AH0', 'N', 'S', 'T', ' ', 'T', 'UW1', ' ', 'D', 'EH1', 'TH', ' ',
#         'F', 'AO1', 'R', ' ', 'F', 'AO1', 'R', 'JH', 'IH0', 'NG', ' ', 'W',
#         'IH1', 'L', 'Z', '.'], dtype='<U3'),
#  array(['S', 'IH1', 'N', 'S', ' ', 'DH', 'IY1', 'Z', ' ', 'EY1', 'JH',
#         'AH0', 'N', 'S', 'IY0', 'Z', ' ', 'AA1', 'R', ' ', 'AO0', 'L', 'R',
#         'EH1', 'D', 'IY0', ' ', 'AH0', 'B', 'L', 'AY1', 'JH', 'D', ' ',
#         'K', 'AA1', 'N', 'S', 'T', 'AH0', 'N', 'T', 'L', 'IY0', ' ', 'T',
#         'UW1', ' ', 'IH0', 'V', 'AE1', 'L', 'Y', 'UW0', 'EY2', 'T', ' ',
#         'DH', 'AH0', ' ', 'AE0', 'K', 'T', 'IH1', 'V', 'IH0', 'T', 'IY0',
#         'Z', ' ', 'AH1', 'V', ' ', 'S', 'AH1', 'CH', ' ', 'G', 'R', 'UW1',
#         'P', 'S', ','], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'N', 'AY1', 'N', 'T', 'IY1', 'N', ' ', 'TH',
#         'ER1', 'T', 'R', 'IY0', 'EH2', 'TH', ' ', 'Y', 'UW1', ' ', 'AH0',
#         'N', 'D', ' ', 'AY1', ' ', 'N', 'UW1', ' ', 'DH', 'AE1', 'T', ' ',
#         'W', 'IY1', ' ', 'M', 'AH1', 'S', 'T', ' ', 'N', 'EH1', 'V', 'ER0',
#         ' ', 'L', 'EH1', 'T', ' ', 'AW1', 'ER0', ' ', 'EH2', 'K', 'AH0',
#         'N', 'AA1', 'M', 'IH0', 'K', ' ', 'S', 'IH1', 'S', 'T', 'AH0', 'M',
#         ' ', 'G', 'EH1', 'T', ' ', 'K', 'AH0', 'M', 'P', 'L', 'IY1', 'T',
#         'L', 'IY0', ' ', 'AW1', 'T', ' ', 'AH1', 'V', ' ', 'JH', 'OY1',
#         'N', 'T', ' ', 'AH0', 'G', 'EH1', 'N'], dtype='<U3'),
#  array(['W', 'IY1', ' ', 'W', 'IH1', 'L', ' ', 'N', 'AA1', 'T', ' ', 'AH0',
#         'L', 'AW1', ' ', 'AW0', 'ER0', 'S', 'EH1', 'L', 'V', 'Z', ' ', 'T',
#         'UW1', ' ', 'R', 'AH1', 'N', ' ', 'ER0', 'AW1', 'N', 'D', ' ',
#         'IH0', 'N', ' ', 'N', 'UW1', ' ', 'S', 'ER1', 'K', 'AH0', 'L', 'Z',
#         ' ', 'AH1', 'V', ' ', 'F', 'Y', 'UW1', 'T', 'AH0', 'L', ' ', 'D',
#         'IH0', 'S', 'K', 'AH1', 'SH', 'AH0', 'N', ' ', 'AH0', 'N', 'D',
#         ' ', 'D', 'AH0', 'B', 'EY1', 'T', ',', ' ', 'AO1', 'L', 'W', 'EY2',
#         'Z', ' ', 'P', 'OW0', 'S', 'T', 'P', 'OW1', 'N', 'IH0', 'NG', ' ',
#         'DH', 'AH0', ' ', 'D', 'EY1', ' ', 'AH1', 'V', ' ', 'D', 'IH0',
#         'S', 'IH1', 'ZH', 'AH0', 'N', '.'], dtype='<U3'),
#  array(['EH1', 'F', 'B', 'IY1', 'AY1', ',', ' ', 'AH0', 'N', 'D', ' ',
#         'DH', 'AH0', ' ', 'S', 'IY1', 'K', 'R', 'AH0', 'T', ' ', 'S',
#         'ER1', 'V', 'AH0', 'S', '.'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'TH', 'R', 'IY1', ' ', 'HH', 'AO1', 'R', 'S',
#         'AH0', 'Z', ' ', 'AA1', 'R', ',', ' ', 'AH1', 'V', ' ', 'K', 'AO1',
#         'R', 'S', ',', ' ', 'DH', 'AH0', ' ', 'TH', 'R', 'IY1', ' ', 'B',
#         'R', 'AE1', 'N', 'CH', 'AH0', 'Z', ' ', 'AH1', 'V', ' ', 'G',
#         'AH1', 'V', 'ER0', 'N', 'M', 'AH0', 'N', 'T', ' ', '-', '-', 'AH0',
#         ' ', 'K', 'AA1', 'NG', 'G', 'R', 'AH0', 'S', ',', ' ', 'DH', 'AH0',
#         ' ', 'IH0', 'G', 'Z', 'EH1', 'K', 'Y', 'AH0', 'T', 'IH0', 'V', ' ',
#         'AH0', 'N', 'D', ' ', 'DH', 'AH0', ' ', 'K', 'AO1', 'R', 'T', 'S',
#         '.'], dtype='<U3'),
#  array(['IH1', 'T', ' ', 'IH1', 'Z', ' ', 'AE1', 'N', ' ', 'IY1', 'Z',
#         'IY0', ' ', 'D', 'AA1', 'K', 'Y', 'AH0', 'M', 'AH0', 'N', 'T', ' ',
#         'T', 'UW1', ' ', 'AH2', 'N', 'D', 'ER0', 'S', 'T', 'AE1', 'N', 'D',
#         ' ', 'W', 'EH1', 'N', ' ', 'Y', 'UW1', ' ', 'R', 'IH0', 'M', 'EH1',
#         'M', 'B', 'ER0', ' ', 'DH', 'AE1', 'T', ' ', 'IH1', 'T', ' ', 'W',
#         'AA1', 'Z', ' ', 'K', 'AO1', 'L', 'D', ' ', 'IH0', 'N', 'T', 'UW1',
#         ' ', 'B', 'IY1', 'IH0', 'NG'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'S', 'IY1', 'K', 'R', 'AH0', 'T', ' ', 'S',
#         'ER1', 'V', 'AH0', 'S', ' ', 'SH', 'UH1', 'D', ' ', 'N', 'AA1',
#         'T', ' ', 'AH0', 'N', 'D', ' ', 'D', 'AH1', 'Z', ' ', 'N', 'AA1',
#         'T', ' ', 'P', 'L', 'AE1', 'N', ' ', 'T', 'UW1', ' ', 'D', 'IH0',
#         'V', 'EH1', 'L', 'AH0', 'P', ' ', 'IH1', 'T', 'S', ' ', 'OW1', 'N',
#         ' ', 'IH2', 'N', 'T', 'EH1', 'L', 'AH0', 'JH', 'AH0', 'N', 'S',
#         ' ', 'G', 'AE1', 'DH', 'ER0', 'IH0', 'NG', ' ', 'F', 'AH0', 'S',
#         'IH1', 'L', 'AH0', 'T', 'IY0', 'Z', ' ', 'T', 'UW1', ' ', 'D',
#         'UW1', 'P', 'L', 'AH0', 'K', 'AH0', 'T', ' ', 'DH', 'AH0', ' ',
#         'IH0', 'G', 'Z', 'IH1', 'S', 'T', 'IH0', 'NG', ' ', 'F', 'AH0',
#         'S', 'IH1', 'L', 'AH0', 'T', 'IY0', 'Z', ' ', 'AH1', 'V', ' ',
#         'AH1', 'DH', 'ER0', ' ', 'F', 'EH1', 'D', 'ER0', 'AH0', 'L', ' ',
#         'EY1', 'JH', 'AH0', 'N', 'S', 'IY0', 'Z', '.'], dtype='<U3'),
#  array(['IH0', 'N', ' ', 'P', 'L', 'AE1', 'N', 'IH0', 'NG', ' ', 'IH1',
#         'T', 'S', ' ', 'D', 'EY1', 'T', 'AH0', ' ', 'P', 'R', 'AA1', 'S',
#         'EH0', 'S', 'IH0', 'NG', ' ', 'T', 'EH0', 'K', 'N', 'IY1', 'K',
#         'S', ','], dtype='<U3'),
#  array(['N', 'AY1', 'N', 'T', 'IY1', 'N', ' ', 'D', 'AA1', 'L', 'ER0', 'Z',
#         ',', ' ', 'N', 'AY1', 'N', 'T', 'IH0', 'F', 'AY2', 'T', 'ER0', ' ',
#         'S', 'EH1', 'N', 'T', 'S', ',', ' ', 'P', 'L', 'AH1', 'S', ' ',
#         'W', 'AH1', 'N', ' ', 'D', 'AA1', 'L', 'ER0', ',', ' ', 'T', 'W',
#         'EH2', 'N', 'T', 'IY0', 'S', 'EH1', 'V', 'AH0', 'N', ' ', 'S',
#         'EH1', 'N', 'T', 'S', ' ', 'SH', 'IH1', 'P', 'IH0', 'NG', ' ',
#         'CH', 'AA1', 'R', 'JH', ',', ' ', 'HH', 'AE1', 'D', ' ', 'B',
#         'IH1', 'N', ' ', 'K', 'AH0', 'L', 'EH1', 'K', 'T', 'AH0', 'D', ' ',
#         'F', 'R', 'AH1', 'M', ' ', 'DH', 'AH0', ' ', 'K', 'AH0', 'N', 'S',
#         'AY1', 'G', 'N', 'IY2', ',', ' ', 'HH', 'AY1', 'D', 'AH0', 'L',
#         '.'], dtype='<U3'),
#  array(['DH', 'AE1', 'T', ' ', 'IH1', 'Z', ' ', 'N', 'AA1', 'T', ' ',
#         'OW1', 'N', 'L', 'IY0', ' ', 'M', 'AY1', ' ', 'AE2', 'K', 'Y',
#         'AH0', 'Z', 'EY1', 'SH', 'AH0', 'N', '.'], dtype='<U3'),
#  array(['IY1', 'CH', ' ', 'P', 'AH0', 'T', 'R', 'OW1', 'L', 'M', 'AE2',
#         'N', ' ', 'M', 'AY1', 'T', ' ', 'B', 'IY1', ' ', 'G', 'IH1', 'V',
#         'AH0', 'N', ' ', 'EY1', ' ', 'P', 'R', 'IY0', 'P', 'EH1', 'R', 'D',
#         ' ', 'B', 'UH1', 'K', 'L', 'IH0', 'T', ' ', 'AH1', 'V', ' ', 'IH2',
#         'N', 'S', 'T', 'R', 'AH1', 'K', 'SH', 'AH0', 'N', 'Z', ' ', 'IH0',
#         'K', 'S', 'P', 'L', 'EY1', 'N', 'IH0', 'NG', ' ', 'W', 'AH1', 'T',
#         ' ', 'IH1', 'Z', ' ', 'IH0', 'K', 'S', 'P', 'EH1', 'K', 'T', 'AH0',
#         'D', ' ', 'AH1', 'V', ' ', 'HH', 'IH1', 'M', '.', ' ', 'DH', 'AH0',
#         ' ', 'S', 'IY1', 'K', 'R', 'AH0', 'T', ' ', 'S', 'ER1', 'V', 'AH0',
#         'S', ' ', 'HH', 'AE1', 'Z', ' ', 'IH0', 'K', 'S', 'P', 'R', 'EH1',
#         'S', 'T', ' ', 'K', 'AH0', 'N', 'S', 'ER1', 'N'], dtype='<U3'),
#  array(['M', 'IH1', 'S', 'T', 'ER0', '.', ' ', 'M', 'AH1', 'L', 'EY0', ' ',
#         'K', 'AO1', 'L', 'D', ' ', 'AH0', 'G', 'EH1', 'N', ',', ' ', 'T',
#         'EY1', 'K', 'IH0', 'NG', ' ', 'W', 'IH1', 'DH', ' ', 'HH', 'IH1',
#         'M', ' ', 'F', 'AY1', 'V', ' ', 'HH', 'AH1', 'N', 'D', 'R', 'AH0',
#         'D', ' ', 'P', 'AW1', 'N', 'D', 'Z', ' ', 'IH0', 'N', ' ', 'K',
#         'AE1', 'SH', '.', ' ', 'HH', 'AW1', 'ER0', 'D', ' ', 'D', 'IH0',
#         'S', 'K', 'AH1', 'V', 'ER0', 'D', ' ', 'DH', 'IH1', 'S', ',', ' ',
#         'AH0', 'N', 'D', ' ', 'HH', 'IH1', 'Z', ' ', 'M', 'AE1', 'N',
#         'ER0', ' ', 'W', 'AA1', 'Z', ' ', 'V', 'EH1', 'R', 'IY0', ' ', 'S',
#         'AH0', 'S', 'P', 'IH1', 'SH', 'AH0', 'S', ';'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'AH0', 'S', 'IH1', 'S', 'T', 'AH0', 'N', 'T',
#         ' ', 'T', 'UW1', ' ', 'DH', 'AH0', ' ', 'D', 'ER0', 'EH1', 'K',
#         'T', 'ER0', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ', 'EH1', 'F',
#         'B', 'IY1', 'AY1', ' ', 'T', 'EH1', 'S', 'T', 'IH0', 'F', 'AY2',
#         'D', ' ', 'DH', 'AE1', 'T'], dtype='<U3'),
#  array(['DH', 'AH0', ' ', 'P', 'L', 'AE1', 'N', ' ', 'P', 'R', 'AH0', 'V',
#         'AY1', 'D', 'Z', ' ', 'F', 'AO1', 'R', ' ', 'AE1', 'N', ' ', 'AH0',
#         'D', 'IH1', 'SH', 'AH0', 'N', 'AH0', 'L', ' ', 'T', 'UW1', ' ',
#         'HH', 'AH1', 'N', 'D', 'R', 'AH0', 'D', ' ', 'F', 'AY1', 'V', ' ',
#         'EY1', 'JH', 'AH0', 'N', 'T', 'S', ' ', 'F', 'AO1', 'R', ' ', 'DH',
#         'AH0', ' ', 'S', 'IY1', 'K', 'R', 'AH0', 'T', ' ', 'S', 'ER1', 'V',
#         'AH0', 'S', '.', ' ', 'S', 'EH1', 'V', 'AH0', 'N', 'T', 'IY1', 'N',
#         ' ', 'AH1', 'V', ' ', 'DH', 'IH1', 'S', ' ', 'N', 'AH1', 'M', 'B',
#         'ER0', ' ', 'AA1', 'R', ' ', 'P', 'R', 'AH0', 'P', 'OW1', 'Z', 'D',
#         ' ', 'F', 'AO1', 'R', ' ', 'DH', 'AH0', ' ', 'P', 'R', 'AH0', 'T',
#         'EH1', 'K', 'T', 'IH0', 'V', ' ', 'R', 'IY0', 'S', 'ER1', 'CH',
#         ' ', 'S', 'EH1', 'K', 'SH', 'AH0', 'N', ';'], dtype='<U3'),
#  array(['IH1', 'T', ' ', 'HH', 'AE1', 'Z', ' ', 'AO1', 'L', 'S', 'OW0',
#         ' ', 'Y', 'UW1', 'Z', 'D', ' ', 'AH1', 'DH', 'ER0', ' ', 'F',
#         'EH1', 'D', 'ER0', 'AH0', 'L', ' ', 'L', 'AO1', ' ', 'EH0', 'N',
#         'F', 'AO1', 'R', 'S', 'M', 'AH0', 'N', 'T', ' ', 'EY1', 'JH',
#         'AH0', 'N', 'T', 'S', ' ', 'D', 'UH1', 'R', 'IH0', 'NG', ' ', 'P',
#         'R', 'EH2', 'Z', 'IH0', 'D', 'EH1', 'N', 'SH', 'AH0', 'L', ' ',
#         'V', 'IH1', 'Z', 'IH0', 'T', 'S', ' ', 'T', 'UW1', ' ', 'S', 'IH1',
#         'T', 'IY0', 'Z', ' ', 'IH0', 'N', ' ', 'W', 'IH1', 'CH', ' ', 'S',
#         'AH1', 'CH', ' ', 'EY1', 'JH', 'AH0', 'N', 'T', 'S', ' ', 'AA1',
#         'R', ' ', 'S', 'T', 'EY1', 'SH', 'AH0', 'N', 'D', '.'], dtype='<U3'),
#  array(['W', 'IY1', 'D', 'AH0', 'N', ' ', 'AH0', 'N', 'D', ' ', 'L', 'EH1',
#         'K', 'S', 'AA2', 'R', ' ', 'T', 'UW1', ' ', 'T', 'W', 'EH1', 'L',
#         'V', ' ', 'AH0', 'N', 'D', ' ', 'S', 'IH1', 'K', 'S', ' ', 'M',
#         'AH1', 'N', 'TH', 'S', ' ', 'R', 'IH0', 'S', 'P', 'EH1', 'K', 'T',
#         'IH0', 'V', 'L', 'IY0', ' ', 'IH0', 'N', ' ', 'K', 'OW1', 'L', 'D',
#         'B', 'AA0', 'TH', ' ', 'F', 'IY1', 'L', 'D', 'Z', '.'], dtype='<U3'),
#  array(['AE1', 'T', ' ', 'F', 'AO1', 'R', 'T', 'IY1', 'N', ' ', 'HH',
#         'IY1', ' ', 'W', 'AA1', 'Z', ' ', 'EY1', ' ', 'P', 'IH1', 'K', 'P',
#         'AA2', 'K', 'AH0', 'T', ' ', 'AH0', 'N', 'D', ' ', 'EY1', ' ', 'D',
#         'AH1', 'F', 'ER0', ',', ' ', 'AO1', 'R', ' ', 'EY1', ' ', 'S',
#         'EH1', 'L', 'ER0', ' ', 'AH1', 'V', ' ', 'SH', 'AE1', 'M', ' ',
#         'G', 'UH1', 'D', 'Z', '.'], dtype='<U3'),
#  array(['L', 'EH1', 'D', ' ', 'HH', 'IH1', 'M', ' ', 'T', 'UW1', ' ', 'TH',
#         'IH1', 'NG', 'K', ' ', 'S', 'IH1', 'R', 'IY0', 'AH0', 'S', 'L',
#         'IY0', ' ', 'AH1', 'V', ' ', 'T', 'R', 'AY1', 'IH0', 'NG', ' ',
#         'HH', 'IH1', 'Z', ' ', 'F', 'AO1', 'R', 'CH', 'AH0', 'N', 'Z', ' ',
#         'IH0', 'N', ' ', 'AH0', 'N', 'AH1', 'DH', 'ER0', ' ', 'L', 'AE1',
#         'N', 'D', '.'], dtype='<U3'),
#  array(['S', 'AA1', 'L', 'AH0', 'M', 'AH0', 'N', 'Z', ',', ' ', 'W', 'AY1',
#         'L', ' ', 'W', 'EY1', 'T', 'IH0', 'NG', ' ', 'T', 'UW1', ' ',
#         'AH0', 'P', 'IH1', 'R', ' ', 'IH0', 'N', ' ', 'K', 'AO1', 'R', 'T',
#         ',', ' ', 'P', 'ER0', 'S', 'W', 'EY1', 'D', 'AH0', 'D', ' ', 'DH',
#         'AH0', ' ', 'T', 'ER1', 'K', 'N', 'IY0', 'Z', ' ', 'T', 'UW1', ' ',
#         'T', 'EY1', 'K', ' ', 'HH', 'IH1', 'M', ' ', 'T', 'UW1', ' ',
#         'EY1', ' ', 'P', 'AH1', 'B', 'L', 'IH0', 'K', 'AW2', 'S', ',', ' ',
#         'W', 'EH1', 'R', ' ', 'AO1', 'L', ' ', 'M', 'AY1', 'T', ' ', 'R',
#         'IH0', 'F', 'R', 'EH1', 'SH', '.'], dtype='<U3'),
#  array(['B', 'AH1', 'T', ' ', 'M', 'IH1', 'S', 'IH0', 'Z', '.', ' ', 'S',
#         'AA1', 'L', 'AH0', 'M', 'AH0', 'N', 'Z', ' ', 'K', 'UH1', 'D', ' ',
#         'N', 'AA1', 'T', ' ', 'R', 'IH0', 'Z', 'IH1', 'S', 'T', ' ', 'DH',
#         'AH0', ' ', 'T', 'EH0', 'M', 'T', 'EY1', 'SH', 'AH0', 'N', ' ',
#         'T', 'UW1', ' ', 'D', 'AE1', 'B', 'AH0', 'L', ' ', 'IH0', 'N', ' ',
#         'S', 'T', 'OW1', 'L', 'AH0', 'N', ' ', 'G', 'UH1', 'D', 'Z', ',',
#         ' ', 'AH0', 'N', 'D', ' ', 'SH', 'IY1', ' ', 'W', 'AA1', 'Z', ' ',
#         'F', 'AW1', 'N', 'D', ' ', 'SH', 'IH1', 'P', 'IH0', 'NG', ' ', 'W',
#         'AA1', 'CH', 'AH0', 'Z', ' ', 'AH1', 'V', ' ', 'DH', 'AH0', ' ',
#         'R', 'AO1', 'NG', ' ', 'K', 'AE1', 'T', 'AH0', 'G', 'AO2', 'R',
#         'IY0', ' ', 'T', 'UW1', ' ', 'N', 'UW1', ' ', 'Y', 'AO1', 'R', 'K',
#         '.'], dtype='<U3')]

# %%
len(npz_files)
# Out:
# 12500
