# %%
import pandas as pd
from matplotlib import pyplot as plt

file_path = '/nas/users/dahye/kw/tts/ttsxai/logs/probe_prosody/LJSpeech/tacotron2_waveglow/duration/2024_02_01_22_26_20/seed_0/progress.csv'
df = pd.read_csv(file_path)

# %%
plt.plot(df['Epoch'].values, df['train/Loss'], label='train loss')
plt.plot(df['Epoch'].values, df['val/Loss'], label='val loss')
plt.legend()
